# %% [markdown]
# ### Imports

# %%
import os, time, pickle, random, time
from datetime import datetime
import numpy as np
from time import localtime, strftime
import logging, scipy
import tensorflow as tf
import tensorlayer as tl
from model import SRGAN_g, SRGAN_d, Vgg19_simple_api
from utils import *
from config import config, log_config
from matplotlib.pyplot import imshow
import numpy as np
from PIL import Image
import random

# %% [markdown]
# ### Hyper Params

# %%
## Adam
batch_size = config.TRAIN.batch_size
lr_init = config.TRAIN.lr_init
beta1 = config.TRAIN.beta1
## initialize G
n_epoch_init = 5
## adversarial learning (SRGAN)
n_epoch = 1000
lr_decay = config.TRAIN.lr_decay
decay_every = config.TRAIN.decay_every
ni = int(np.sqrt(batch_size))

# %% [markdown]
# ### Dirs and Stuff

# %%
## create folders to save result images and trained model
save_dir_ginit = "samples/{}_ginit".format("srgan")
save_dir_gan = "samples/{}_gan".format("srgan")
tl.files.exists_or_mkdir(save_dir_ginit)
tl.files.exists_or_mkdir(save_dir_gan)
checkpoint_dir = "checkpoint"  # checkpoint_resize_conv
tl.files.exists_or_mkdir(checkpoint_dir)
# Out:
# [TL] [!] samples/srgan_ginit exists ...
# [TL] [!] samples/srgan_gan exists ...
# [TL] [!] checkpoint exists ...
# True

# %% [markdown]
# ### Data

# %%
train_hr_img_list = sorted(tl.files.load_file_list(path=config.TRAIN.hr_img_path, regx='.*.png', printable=False))
train_lr_img_list = sorted(tl.files.load_file_list(path=config.TRAIN.lr_img_path, regx='.*.png', printable=False))
valid_hr_img_list = sorted(tl.files.load_file_list(path=config.VALID.hr_img_path, regx='.*.png', printable=False))
valid_lr_img_list = sorted(tl.files.load_file_list(path=config.VALID.lr_img_path, regx='.*.png', printable=False))

# %%
train_hr_imgs = tl.vis.read_images(train_hr_img_list, path=config.TRAIN.hr_img_path, n_threads=32)
train_lr_img = tl.vis.read_images(train_lr_img_list, path=config.TRAIN.lr_img_path, n_threads=32)
valid_hr_img = tl.vis.read_images(valid_hr_img_list, path=config.VALID.hr_img_path, n_threads=32)
valid_lr_img = tl.vis.read_images(valid_lr_img_list, path=config.VALID.lr_img_path, n_threads=32)
# Out:
# [TL] read 32 from mainDataset/train/HR
# [TL] read 64 from mainDataset/train/HR
# [TL] read 96 from mainDataset/train/HR
# [TL] read 128 from mainDataset/train/HR
# [TL] read 160 from mainDataset/train/HR
# [TL] read 192 from mainDataset/train/HR
# [TL] read 224 from mainDataset/train/HR
# [TL] read 256 from mainDataset/train/HR
# [TL] read 288 from mainDataset/train/HR
# [TL] read 320 from mainDataset/train/HR
# [TL] read 352 from mainDataset/train/HR
# [TL] read 384 from mainDataset/train/HR
# [TL] read 416 from mainDataset/train/HR
# [TL] read 448 from mainDataset/train/HR
# [TL] read 480 from mainDataset/train/HR
# [TL] read 512 from mainDataset/train/HR
# [TL] read 544 from mainDataset/train/HR
# [TL] read 576 from mainDataset/train/HR
# [TL] read 608 from mainDataset/train/HR
# [TL] read 640 from mainDataset/train/HR
# [TL] read 672 from mainDataset/train/HR
# [TL] read 704 from mainDataset/train/HR
# [TL] read 736 from mainDataset/train/HR
# [TL] read 768 from mainDataset/train/HR
# [TL] read 800 from mainDataset/train/HR
# [TL] read 832 from mainDataset/train/HR
# [TL] read 864 from mainDataset/train/HR
# [TL] read 896 from mainDataset/train/HR
# [TL] read 928 from mainDataset/train/HR
# [TL] read 960 from mainDataset/train/HR
# [TL] read 992 from mainDataset/train/HR
# [TL] read 1024 from mainDataset/train/HR
# [TL] read 1056 from mainDataset/train/HR
# [TL] read 1088 from mainDataset/train/HR
# [TL] read 1120 from mainDataset/train/HR
# [TL] read 1152 from mainDataset/train/HR
# [TL] read 1184 from mainDataset/train/HR
# [TL] read 1216 from mainDataset/train/HR
# [TL] read 1248 from mainDataset/train/HR
# [TL] read 1280 from mainDataset/train/HR
# [TL] read 1312 from mainDataset/train/HR
# [TL] read 1344 from mainDataset/train/HR
# [TL] read 1376 from mainDataset/train/HR
# [TL] read 1408 from mainDataset/train/HR
# [TL] read 1440 from mainDataset/train/HR
# [TL] read 1472 from mainDataset/train/HR
# [TL] read 1504 from mainDataset/train/HR
# [TL] read 1536 from mainDataset/train/HR
# [TL] read 1568 from mainDataset/train/HR
# [TL] read 1600 from mainDataset/train/HR
# [TL] read 1632 from mainDataset/train/HR
# [TL] read 1664 from mainDataset/train/HR
# [TL] read 1696 from mainDataset/train/HR
# [TL] read 1728 from mainDataset/train/HR
# [TL] read 1760 from mainDataset/train/HR
# [TL] read 1792 from mainDataset/train/HR
# [TL] read 1824 from mainDataset/train/HR
# [TL] read 1856 from mainDataset/train/HR
# [TL] read 1888 from mainDataset/train/HR
# [TL] read 1920 from mainDataset/train/HR
# [TL] read 1952 from mainDataset/train/HR
# [TL] read 1984 from mainDataset/train/HR
# [TL] read 2016 from mainDataset/train/HR
# [TL] read 2048 from mainDataset/train/HR
# [TL] read 2080 from mainDataset/train/HR
# [TL] read 2112 from mainDataset/train/HR
# [TL] read 2144 from mainDataset/train/HR
# [TL] read 2176 from mainDataset/train/HR
# [TL] read 2208 from mainDataset/train/HR
# [TL] read 2240 from mainDataset/train/HR
# [TL] read 2272 from mainDataset/train/HR
# [TL] read 2304 from mainDataset/train/HR
# [TL] read 2336 from mainDataset/train/HR
# [TL] read 2368 from mainDataset/train/HR
# [TL] read 2400 from mainDataset/train/HR
# [TL] read 2432 from mainDataset/train/HR
# [TL] read 2464 from mainDataset/train/HR
# [TL] read 2496 from mainDataset/train/HR
# [TL] read 2528 from mainDataset/train/HR
# [TL] read 2560 from mainDataset/train/HR
# [TL] read 2592 from mainDataset/train/HR
# [TL] read 2624 from mainDataset/train/HR
# [TL] read 2656 from mainDataset/train/HR
# [TL] read 2688 from mainDataset/train/HR
# [TL] read 2720 from mainDataset/train/HR
# [TL] read 2752 from mainDataset/train/HR
# [TL] read 2784 from mainDataset/train/HR
# [TL] read 2816 from mainDataset/train/HR
# [TL] read 2848 from mainDataset/train/HR
# [TL] read 2880 from mainDataset/train/HR
# [TL] read 2912 from mainDataset/train/HR
# [TL] read 2920 from mainDataset/train/HR
# [TL] read 32 from mainDataset/train/LR
# [TL] read 64 from mainDataset/train/LR
# [TL] read 96 from mainDataset/train/LR
# [TL] read 128 from mainDataset/train/LR
# [TL] read 160 from mainDataset/train/LR
# [TL] read 192 from mainDataset/train/LR
# [TL] read 224 from mainDataset/train/LR
# [TL] read 256 from mainDataset/train/LR
# [TL] read 288 from mainDataset/train/LR
# [TL] read 320 from mainDataset/train/LR
# [TL] read 352 from mainDataset/train/LR
# [TL] read 384 from mainDataset/train/LR
# [TL] read 416 from mainDataset/train/LR
# [TL] read 448 from mainDataset/train/LR
# [TL] read 480 from mainDataset/train/LR
# [TL] read 512 from mainDataset/train/LR
# [TL] read 544 from mainDataset/train/LR
# [TL] read 576 from mainDataset/train/LR
# [TL] read 608 from mainDataset/train/LR
# [TL] read 640 from mainDataset/train/LR
# [TL] read 672 from mainDataset/train/LR
# [TL] read 704 from mainDataset/train/LR
# [TL] read 736 from mainDataset/train/LR
# [TL] read 768 from mainDataset/train/LR
# [TL] read 800 from mainDataset/train/LR
# [TL] read 832 from mainDataset/train/LR
# [TL] read 864 from mainDataset/train/LR
# [TL] read 896 from mainDataset/train/LR
# [TL] read 928 from mainDataset/train/LR
# [TL] read 960 from mainDataset/train/LR
# [TL] read 992 from mainDataset/train/LR
# [TL] read 1024 from mainDataset/train/LR
# [TL] read 1056 from mainDataset/train/LR
# [TL] read 1088 from mainDataset/train/LR
# [TL] read 1120 from mainDataset/train/LR
# [TL] read 1152 from mainDataset/train/LR
# [TL] read 1184 from mainDataset/train/LR
# [TL] read 1216 from mainDataset/train/LR
# [TL] read 1248 from mainDataset/train/LR
# [TL] read 1280 from mainDataset/train/LR
# [TL] read 1312 from mainDataset/train/LR
# [TL] read 1344 from mainDataset/train/LR
# [TL] read 1376 from mainDataset/train/LR
# [TL] read 1408 from mainDataset/train/LR
# [TL] read 1440 from mainDataset/train/LR
# [TL] read 1472 from mainDataset/train/LR
# [TL] read 1504 from mainDataset/train/LR
# [TL] read 1536 from mainDataset/train/LR
# [TL] read 1568 from mainDataset/train/LR
# [TL] read 1600 from mainDataset/train/LR
# [TL] read 1632 from mainDataset/train/LR
# [TL] read 1664 from mainDataset/train/LR
# [TL] read 1696 from mainDataset/train/LR
# [TL] read 1728 from mainDataset/train/LR
# [TL] read 1760 from mainDataset/train/LR
# [TL] read 1792 from mainDataset/train/LR
# [TL] read 1824 from mainDataset/train/LR
# [TL] read 1856 from mainDataset/train/LR
# [TL] read 1888 from mainDataset/train/LR
# [TL] read 1920 from mainDataset/train/LR
# [TL] read 1952 from mainDataset/train/LR
# [TL] read 1984 from mainDataset/train/LR
# [TL] read 2016 from mainDataset/train/LR
# [TL] read 2048 from mainDataset/train/LR
# [TL] read 2080 from mainDataset/train/LR
# [TL] read 2112 from mainDataset/train/LR
# [TL] read 2144 from mainDataset/train/LR
# [TL] read 2176 from mainDataset/train/LR
# [TL] read 2208 from mainDataset/train/LR
# [TL] read 2240 from mainDataset/train/LR
# [TL] read 2272 from mainDataset/train/LR
# [TL] read 2304 from mainDataset/train/LR
# [TL] read 2336 from mainDataset/train/LR
# [TL] read 2368 from mainDataset/train/LR
# [TL] read 2400 from mainDataset/train/LR
# [TL] read 2432 from mainDataset/train/LR
# [TL] read 2464 from mainDataset/train/LR
# [TL] read 2496 from mainDataset/train/LR
# [TL] read 2528 from mainDataset/train/LR
# [TL] read 2560 from mainDataset/train/LR
# [TL] read 2592 from mainDataset/train/LR
# [TL] read 2624 from mainDataset/train/LR
# [TL] read 2656 from mainDataset/train/LR
# [TL] read 2688 from mainDataset/train/LR
# [TL] read 2720 from mainDataset/train/LR
# [TL] read 2752 from mainDataset/train/LR
# [TL] read 2784 from mainDataset/train/LR
# [TL] read 2816 from mainDataset/train/LR
# [TL] read 2848 from mainDataset/train/LR
# [TL] read 2880 from mainDataset/train/LR
# [TL] read 2912 from mainDataset/train/LR
# [TL] read 2920 from mainDataset/train/LR
# [TL] read 32 from mainDataset/dev/HR
# [TL] read 64 from mainDataset/dev/HR
# [TL] read 96 from mainDataset/dev/HR
# [TL] read 128 from mainDataset/dev/HR
# [TL] read 160 from mainDataset/dev/HR
# [TL] read 192 from mainDataset/dev/HR
# [TL] read 224 from mainDataset/dev/HR
# [TL] read 256 from mainDataset/dev/HR
# [TL] read 288 from mainDataset/dev/HR
# [TL] read 320 from mainDataset/dev/HR
# [TL] read 352 from mainDataset/dev/HR
# [TL] read 365 from mainDataset/dev/HR
# [TL] read 32 from mainDataset/dev/LR
# [TL] read 64 from mainDataset/dev/LR
# [TL] read 96 from mainDataset/dev/LR
# [TL] read 128 from mainDataset/dev/LR
# [TL] read 160 from mainDataset/dev/LR
# [TL] read 192 from mainDataset/dev/LR
# [TL] read 224 from mainDataset/dev/LR
# [TL] read 256 from mainDataset/dev/LR
# [TL] read 288 from mainDataset/dev/LR
# [TL] read 320 from mainDataset/dev/LR
# [TL] read 352 from mainDataset/dev/LR
# [TL] read 365 from mainDataset/dev/LR

# %%
for dataset in [train_hr_imgs,train_lr_img,valid_hr_img,valid_lr_img]:
    for i,img in enumerate(dataset):
        if len(img.shape) == 2:
            print("B&W")

# %%
'''# Removing B&W images since it causes problems in Channel
for i,img in enumerate(train_hr_imgs):
    if len(img.shape) == 2:
        train_hr_imgs.pop(i)
for i,img in enumerate(train_lr_img):
    if len(img.shape) == 2:
        train_hr_imgs.pop(i)
for i,img in enumerate(valid_hr_img):
    if len(img.shape) == 2:
        train_hr_imgs.pop(i)
for i,img in enumerate(valid_lr_img):
    if len(img.shape) == 2:
        train_hr_imgs.pop(i)   '''
# Out:
# '# Removing B&W images since it causes problems in Channel\nfor i,img in enumerate(train_hr_imgs):\n    if len(img.shape) == 2:\n        train_hr_imgs.pop(i)\nfor i,img in enumerate(train_lr_img):\n    if len(img.shape) == 2:\n        train_hr_imgs.pop(i)\nfor i,img in enumerate(valid_hr_img):\n    if len(img.shape) == 2:\n        train_hr_imgs.pop(i)\nfor i,img in enumerate(valid_lr_img):\n    if len(img.shape) == 2:\n        train_hr_imgs.pop(i)   '

# %%
'''cropDim = 5000
for img in train_hr_imgs:
    minDim = min(img.shape[0:2])
    if cropDim > minDim :
        cropDim = minDim'''
# Out:
# 'cropDim = 5000\nfor img in train_hr_imgs:\n    minDim = min(img.shape[0:2])\n    if cropDim > minDim :\n        cropDim = minDim'

# %%
'''cropDim -= 1+(cropDim-1)%4'''
# Out:
# 'cropDim -= 1+(cropDim-1)%4'

# %%
cropDim=224

# %%
sample_imgs = random.sample(train_hr_imgs, batch_size)
#sample_imgs = tl.vis.read_images(train_hr_img_list[0:batch_size], path=config.TRAIN.hr_img_path, n_threads=32) # if no pre-load train set
sample_imgs_224 = tl.prepro.threading_data(sample_imgs, fn=crop_sub_imgs_fn,dim=cropDim,is_random=False)
print('sample HR sub-image:', sample_imgs_224.shape, sample_imgs_224.min(), sample_imgs_224.max())
sample_imgs_56 = tl.prepro.threading_data(sample_imgs_224,dim=int(cropDim/4),fn=downsample_fn)
print('sample LR sub-image:', sample_imgs_56.shape, sample_imgs_56.min(), sample_imgs_56.max())
tl.vis.save_images(sample_imgs_56, [ni, ni], save_dir_ginit + '/_train_sample_56.png')
tl.vis.save_images(sample_imgs_224, [ni, ni], save_dir_ginit + '/_train_sample_224.png')
tl.vis.save_images(sample_imgs_56, [ni, ni], save_dir_gan + '/_train_sample_56.png')
tl.vis.save_images(sample_imgs_224, [ni, ni], save_dir_gan + '/_train_sample_224.png')
# Out:
# sample HR sub-image: (25, 224, 224, 3) -1.0 1.0
# sample LR sub-image: (25, 56, 56, 3) -1.0 1.0

# %%
t_image = tf.placeholder('float32', [batch_size, int(cropDim/4), int(cropDim/4), 3], name='t_image_input_to_SRGAN_generator')

# %%
t_target_image = tf.placeholder('float32', [batch_size, cropDim, cropDim, 3], name='t_target_image')

# %%
net_g = SRGAN_g(t_image, is_train=True, reuse=False)
# Out:
# [TL] InputLayer  SRGAN_g/in: (25, 56, 56, 3)
# [TL] Conv2d SRGAN_g/n64s1/c: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: relu
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/srgan/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# [TL] Conv2d SRGAN_g/n64s1/c1/0: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b1/0: decay: 0.900000 epsilon: 0.000010 act: relu is_train: True
# [TL] Conv2d SRGAN_g/n64s1/c2/0: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b2/0: decay: 0.900000 epsilon: 0.000010 act: No Activation is_train: True
# [TL] ElementwiseLayer SRGAN_g/b_residual_add/0: size: (25, 56, 56, 64) fn: add
# [TL] Conv2d SRGAN_g/n64s1/c1/1: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b1/1: decay: 0.900000 epsilon: 0.000010 act: relu is_train: True
# [TL] Conv2d SRGAN_g/n64s1/c2/1: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b2/1: decay: 0.900000 epsilon: 0.000010 act: No Activation is_train: True
# [TL] ElementwiseLayer SRGAN_g/b_residual_add/1: size: (25, 56, 56, 64) fn: add
# [TL] Conv2d SRGAN_g/n64s1/c1/2: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b1/2: decay: 0.900000 epsilon: 0.000010 act: relu is_train: True
# [TL] Conv2d SRGAN_g/n64s1/c2/2: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b2/2: decay: 0.900000 epsilon: 0.000010 act: No Activation is_train: True
# [TL] ElementwiseLayer SRGAN_g/b_residual_add/2: size: (25, 56, 56, 64) fn: add
# [TL] Conv2d SRGAN_g/n64s1/c1/3: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b1/3: decay: 0.900000 epsilon: 0.000010 act: relu is_train: True
# [TL] Conv2d SRGAN_g/n64s1/c2/3: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b2/3: decay: 0.900000 epsilon: 0.000010 act: No Activation is_train: True
# [TL] ElementwiseLayer SRGAN_g/b_residual_add/3: size: (25, 56, 56, 64) fn: add
# [TL] Conv2d SRGAN_g/n64s1/c1/4: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b1/4: decay: 0.900000 epsilon: 0.000010 act: relu is_train: True
# [TL] Conv2d SRGAN_g/n64s1/c2/4: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b2/4: decay: 0.900000 epsilon: 0.000010 act: No Activation is_train: True
# [TL] ElementwiseLayer SRGAN_g/b_residual_add/4: size: (25, 56, 56, 64) fn: add
# [TL] Conv2d SRGAN_g/n64s1/c1/5: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b1/5: decay: 0.900000 epsilon: 0.000010 act: relu is_train: True
# [TL] Conv2d SRGAN_g/n64s1/c2/5: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b2/5: decay: 0.900000 epsilon: 0.000010 act: No Activation is_train: True
# [TL] ElementwiseLayer SRGAN_g/b_residual_add/5: size: (25, 56, 56, 64) fn: add
# [TL] Conv2d SRGAN_g/n64s1/c1/6: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b1/6: decay: 0.900000 epsilon: 0.000010 act: relu is_train: True
# [TL] Conv2d SRGAN_g/n64s1/c2/6: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b2/6: decay: 0.900000 epsilon: 0.000010 act: No Activation is_train: True
# [TL] ElementwiseLayer SRGAN_g/b_residual_add/6: size: (25, 56, 56, 64) fn: add
# [TL] Conv2d SRGAN_g/n64s1/c1/7: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b1/7: decay: 0.900000 epsilon: 0.000010 act: relu is_train: True
# [TL] Conv2d SRGAN_g/n64s1/c2/7: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b2/7: decay: 0.900000 epsilon: 0.000010 act: No Activation is_train: True
# [TL] ElementwiseLayer SRGAN_g/b_residual_add/7: size: (25, 56, 56, 64) fn: add
# [TL] Conv2d SRGAN_g/n64s1/c1/8: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b1/8: decay: 0.900000 epsilon: 0.000010 act: relu is_train: True
# [TL] Conv2d SRGAN_g/n64s1/c2/8: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b2/8: decay: 0.900000 epsilon: 0.000010 act: No Activation is_train: True
# [TL] ElementwiseLayer SRGAN_g/b_residual_add/8: size: (25, 56, 56, 64) fn: add
# [TL] Conv2d SRGAN_g/n64s1/c1/9: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b1/9: decay: 0.900000 epsilon: 0.000010 act: relu is_train: True
# [TL] Conv2d SRGAN_g/n64s1/c2/9: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b2/9: decay: 0.900000 epsilon: 0.000010 act: No Activation is_train: True
# [TL] ElementwiseLayer SRGAN_g/b_residual_add/9: size: (25, 56, 56, 64) fn: add
# [TL] Conv2d SRGAN_g/n64s1/c1/10: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b1/10: decay: 0.900000 epsilon: 0.000010 act: relu is_train: True
# [TL] Conv2d SRGAN_g/n64s1/c2/10: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b2/10: decay: 0.900000 epsilon: 0.000010 act: No Activation is_train: True
# [TL] ElementwiseLayer SRGAN_g/b_residual_add/10: size: (25, 56, 56, 64) fn: add
# [TL] Conv2d SRGAN_g/n64s1/c1/11: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b1/11: decay: 0.900000 epsilon: 0.000010 act: relu is_train: True
# [TL] Conv2d SRGAN_g/n64s1/c2/11: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b2/11: decay: 0.900000 epsilon: 0.000010 act: No Activation is_train: True
# [TL] ElementwiseLayer SRGAN_g/b_residual_add/11: size: (25, 56, 56, 64) fn: add
# [TL] Conv2d SRGAN_g/n64s1/c1/12: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b1/12: decay: 0.900000 epsilon: 0.000010 act: relu is_train: True
# [TL] Conv2d SRGAN_g/n64s1/c2/12: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b2/12: decay: 0.900000 epsilon: 0.000010 act: No Activation is_train: True
# [TL] ElementwiseLayer SRGAN_g/b_residual_add/12: size: (25, 56, 56, 64) fn: add
# [TL] Conv2d SRGAN_g/n64s1/c1/13: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b1/13: decay: 0.900000 epsilon: 0.000010 act: relu is_train: True
# [TL] Conv2d SRGAN_g/n64s1/c2/13: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b2/13: decay: 0.900000 epsilon: 0.000010 act: No Activation is_train: True
# [TL] ElementwiseLayer SRGAN_g/b_residual_add/13: size: (25, 56, 56, 64) fn: add
# [TL] Conv2d SRGAN_g/n64s1/c1/14: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b1/14: decay: 0.900000 epsilon: 0.000010 act: relu is_train: True
# [TL] Conv2d SRGAN_g/n64s1/c2/14: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b2/14: decay: 0.900000 epsilon: 0.000010 act: No Activation is_train: True
# [TL] ElementwiseLayer SRGAN_g/b_residual_add/14: size: (25, 56, 56, 64) fn: add
# [TL] Conv2d SRGAN_g/n64s1/c1/15: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b1/15: decay: 0.900000 epsilon: 0.000010 act: relu is_train: True
# [TL] Conv2d SRGAN_g/n64s1/c2/15: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b2/15: decay: 0.900000 epsilon: 0.000010 act: No Activation is_train: True
# [TL] ElementwiseLayer SRGAN_g/b_residual_add/15: size: (25, 56, 56, 64) fn: add
# [TL] Conv2d SRGAN_g/n64s1/c/m: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b/m: decay: 0.900000 epsilon: 0.000010 act: No Activation is_train: True
# [TL] ElementwiseLayer SRGAN_g/add3: size: (25, 56, 56, 64) fn: add
# [TL] Conv2d SRGAN_g/n256s1/1: n_filter: 256 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] SubpixelConv2d  SRGAN_g/pixelshufflerx2/1: scale: 2 n_out_channel: 64 act: relu
# [TL] Conv2d SRGAN_g/n256s1/2: n_filter: 256 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] SubpixelConv2d  SRGAN_g/pixelshufflerx2/2: scale: 2 n_out_channel: 64 act: relu
# [TL] Conv2d SRGAN_g/out: n_filter: 3 filter_size: (1, 1) strides: (1, 1) pad: SAME act: tanh

# %%
net_d, logits_real = SRGAN_d(t_target_image, is_train=True, reuse=False)
# Out:
# [TL] WARNING: Function: `tensorlayer.layers.utils.set_name_reuse` (in file: /home/ubuntu/anaconda3/envs/srgan/lib/python3.7/site-packages/tensorlayer/layers/utils.py) is deprecated and will be removed after 2018-06-30.
# Instructions for updating: TensorLayer relies on TensorFlow to check name reusing
#
# [TL] WARNING: this method is DEPRECATED and has no effect, please remove it from your code.
# [TL] InputLayer  SRGAN_d/input/images: (25, 224, 224, 3)
# [TL] Conv2d SRGAN_d/h0/c: n_filter: 64 filter_size: (4, 4) strides: (2, 2) pad: SAME act: <lambda>
# [TL] WARNING: Function: `tensorlayer.activation.leaky_relu` (in file: /home/ubuntu/anaconda3/envs/srgan/lib/python3.7/site-packages/tensorlayer/activation.py) is deprecated and will be removed after 2018-09-30.
# Instructions for updating: This API is deprecated. Please use as `tf.nn.leaky_relu`
#
# [TL] Conv2d SRGAN_d/h1/c: n_filter: 128 filter_size: (4, 4) strides: (2, 2) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_d/h1/bn: decay: 0.900000 epsilon: 0.000010 act: <lambda> is_train: True
# [TL] Conv2d SRGAN_d/h2/c: n_filter: 256 filter_size: (4, 4) strides: (2, 2) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_d/h2/bn: decay: 0.900000 epsilon: 0.000010 act: <lambda> is_train: True
# [TL] Conv2d SRGAN_d/h3/c: n_filter: 512 filter_size: (4, 4) strides: (2, 2) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_d/h3/bn: decay: 0.900000 epsilon: 0.000010 act: <lambda> is_train: True
# [TL] Conv2d SRGAN_d/h4/c: n_filter: 1024 filter_size: (4, 4) strides: (2, 2) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_d/h4/bn: decay: 0.900000 epsilon: 0.000010 act: <lambda> is_train: True
# [TL] Conv2d SRGAN_d/h5/c: n_filter: 2048 filter_size: (4, 4) strides: (2, 2) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_d/h5/bn: decay: 0.900000 epsilon: 0.000010 act: <lambda> is_train: True
# [TL] Conv2d SRGAN_d/h6/c: n_filter: 1024 filter_size: (1, 1) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_d/h6/bn: decay: 0.900000 epsilon: 0.000010 act: <lambda> is_train: True
# [TL] Conv2d SRGAN_d/h7/c: n_filter: 512 filter_size: (1, 1) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_d/h7/bn: decay: 0.900000 epsilon: 0.000010 act: No Activation is_train: True
# [TL] Conv2d SRGAN_d/res/c: n_filter: 128 filter_size: (1, 1) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_d/res/bn: decay: 0.900000 epsilon: 0.000010 act: <lambda> is_train: True
# [TL] Conv2d SRGAN_d/res/c2: n_filter: 128 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_d/res/bn2: decay: 0.900000 epsilon: 0.000010 act: <lambda> is_train: True
# [TL] Conv2d SRGAN_d/res/c3: n_filter: 512 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_d/res/bn3: decay: 0.900000 epsilon: 0.000010 act: No Activation is_train: True
# [TL] ElementwiseLayer SRGAN_d/res/add: size: (25, 4, 4, 512) fn: add
# [TL] FlattenLayer SRGAN_d/ho/flatten: 8192
# [TL] DenseLayer  SRGAN_d/ho/dense: 1 No Activation

# %%
_, logits_fake = SRGAN_d(net_g.outputs, is_train=True, reuse=True)
# Out:
# [TL] WARNING: this method is DEPRECATED and has no effect, please remove it from your code.
# [TL] InputLayer  SRGAN_d/input/images: (25, 224, 224, 3)
# [TL] Conv2d SRGAN_d/h0/c: n_filter: 64 filter_size: (4, 4) strides: (2, 2) pad: SAME act: <lambda>
# [TL] Conv2d SRGAN_d/h1/c: n_filter: 128 filter_size: (4, 4) strides: (2, 2) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_d/h1/bn: decay: 0.900000 epsilon: 0.000010 act: <lambda> is_train: True
# [TL] Conv2d SRGAN_d/h2/c: n_filter: 256 filter_size: (4, 4) strides: (2, 2) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_d/h2/bn: decay: 0.900000 epsilon: 0.000010 act: <lambda> is_train: True
# [TL] Conv2d SRGAN_d/h3/c: n_filter: 512 filter_size: (4, 4) strides: (2, 2) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_d/h3/bn: decay: 0.900000 epsilon: 0.000010 act: <lambda> is_train: True
# [TL] Conv2d SRGAN_d/h4/c: n_filter: 1024 filter_size: (4, 4) strides: (2, 2) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_d/h4/bn: decay: 0.900000 epsilon: 0.000010 act: <lambda> is_train: True
# [TL] Conv2d SRGAN_d/h5/c: n_filter: 2048 filter_size: (4, 4) strides: (2, 2) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_d/h5/bn: decay: 0.900000 epsilon: 0.000010 act: <lambda> is_train: True
# [TL] Conv2d SRGAN_d/h6/c: n_filter: 1024 filter_size: (1, 1) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_d/h6/bn: decay: 0.900000 epsilon: 0.000010 act: <lambda> is_train: True
# [TL] Conv2d SRGAN_d/h7/c: n_filter: 512 filter_size: (1, 1) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_d/h7/bn: decay: 0.900000 epsilon: 0.000010 act: No Activation is_train: True
# [TL] Conv2d SRGAN_d/res/c: n_filter: 128 filter_size: (1, 1) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_d/res/bn: decay: 0.900000 epsilon: 0.000010 act: <lambda> is_train: True
# [TL] Conv2d SRGAN_d/res/c2: n_filter: 128 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_d/res/bn2: decay: 0.900000 epsilon: 0.000010 act: <lambda> is_train: True
# [TL] Conv2d SRGAN_d/res/c3: n_filter: 512 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_d/res/bn3: decay: 0.900000 epsilon: 0.000010 act: No Activation is_train: True
# [TL] ElementwiseLayer SRGAN_d/res/add: size: (25, 4, 4, 512) fn: add
# [TL] FlattenLayer SRGAN_d/ho/flatten: 8192
# [TL] DenseLayer  SRGAN_d/ho/dense: 1 No Activation

# %%
net_g.print_params(False)
net_g.print_layers()
net_d.print_params(False)
net_d.print_layers()
# Out:
# [TL]   param   0: SRGAN_g/n64s1/c/kernel:0 (3, 3, 3, 64)      float32_ref
# [TL]   param   1: SRGAN_g/n64s1/c/bias:0 (64,)              float32_ref
# [TL]   param   2: SRGAN_g/n64s1/c1/0/kernel:0 (3, 3, 64, 64)     float32_ref
# [TL]   param   3: SRGAN_g/n64s1/b1/0/beta:0 (64,)              float32_ref
# [TL]   param   4: SRGAN_g/n64s1/b1/0/gamma:0 (64,)              float32_ref
# [TL]   param   5: SRGAN_g/n64s1/b1/0/moving_mean:0 (64,)              float32_ref
# [TL]   param   6: SRGAN_g/n64s1/b1/0/moving_variance:0 (64,)              float32_ref
# [TL]   param   7: SRGAN_g/n64s1/c2/0/kernel:0 (3, 3, 64, 64)     float32_ref
# [TL]   param   8: SRGAN_g/n64s1/b2/0/beta:0 (64,)              float32_ref
# [TL]   param   9: SRGAN_g/n64s1/b2/0/gamma:0 (64,)              float32_ref
# [TL]   param  10: SRGAN_g/n64s1/b2/0/moving_mean:0 (64,)              float32_ref
# [TL]   param  11: SRGAN_g/n64s1/b2/0/moving_variance:0 (64,)              float32_ref
# [TL]   param  12: SRGAN_g/n64s1/c1/1/kernel:0 (3, 3, 64, 64)     float32_ref
# [TL]   param  13: SRGAN_g/n64s1/b1/1/beta:0 (64,)              float32_ref
# [TL]   param  14: SRGAN_g/n64s1/b1/1/gamma:0 (64,)              float32_ref
# [TL]   param  15: SRGAN_g/n64s1/b1/1/moving_mean:0 (64,)              float32_ref
# [TL]   param  16: SRGAN_g/n64s1/b1/1/moving_variance:0 (64,)              float32_ref
# [TL]   param  17: SRGAN_g/n64s1/c2/1/kernel:0 (3, 3, 64, 64)     float32_ref
# [TL]   param  18: SRGAN_g/n64s1/b2/1/beta:0 (64,)              float32_ref
# [TL]   param  19: SRGAN_g/n64s1/b2/1/gamma:0 (64,)              float32_ref
# [TL]   param  20: SRGAN_g/n64s1/b2/1/moving_mean:0 (64,)              float32_ref
# [TL]   param  21: SRGAN_g/n64s1/b2/1/moving_variance:0 (64,)              float32_ref
# [TL]   param  22: SRGAN_g/n64s1/c1/2/kernel:0 (3, 3, 64, 64)     float32_ref
# [TL]   param  23: SRGAN_g/n64s1/b1/2/beta:0 (64,)              float32_ref
# [TL]   param  24: SRGAN_g/n64s1/b1/2/gamma:0 (64,)              float32_ref
# [TL]   param  25: SRGAN_g/n64s1/b1/2/moving_mean:0 (64,)              float32_ref
# [TL]   param  26: SRGAN_g/n64s1/b1/2/moving_variance:0 (64,)              float32_ref
# [TL]   param  27: SRGAN_g/n64s1/c2/2/kernel:0 (3, 3, 64, 64)     float32_ref
# [TL]   param  28: SRGAN_g/n64s1/b2/2/beta:0 (64,)              float32_ref
# [TL]   param  29: SRGAN_g/n64s1/b2/2/gamma:0 (64,)              float32_ref
# [TL]   param  30: SRGAN_g/n64s1/b2/2/moving_mean:0 (64,)              float32_ref
# [TL]   param  31: SRGAN_g/n64s1/b2/2/moving_variance:0 (64,)              float32_ref
# [TL]   param  32: SRGAN_g/n64s1/c1/3/kernel:0 (3, 3, 64, 64)     float32_ref
# [TL]   param  33: SRGAN_g/n64s1/b1/3/beta:0 (64,)              float32_ref
# [TL]   param  34: SRGAN_g/n64s1/b1/3/gamma:0 (64,)              float32_ref
# [TL]   param  35: SRGAN_g/n64s1/b1/3/moving_mean:0 (64,)              float32_ref
# [TL]   param  36: SRGAN_g/n64s1/b1/3/moving_variance:0 (64,)              float32_ref
# [TL]   param  37: SRGAN_g/n64s1/c2/3/kernel:0 (3, 3, 64, 64)     float32_ref
# [TL]   param  38: SRGAN_g/n64s1/b2/3/beta:0 (64,)              float32_ref
# [TL]   param  39: SRGAN_g/n64s1/b2/3/gamma:0 (64,)              float32_ref
# [TL]   param  40: SRGAN_g/n64s1/b2/3/moving_mean:0 (64,)              float32_ref
# [TL]   param  41: SRGAN_g/n64s1/b2/3/moving_variance:0 (64,)              float32_ref
# [TL]   param  42: SRGAN_g/n64s1/c1/4/kernel:0 (3, 3, 64, 64)     float32_ref
# [TL]   param  43: SRGAN_g/n64s1/b1/4/beta:0 (64,)              float32_ref
# [TL]   param  44: SRGAN_g/n64s1/b1/4/gamma:0 (64,)              float32_ref
# [TL]   param  45: SRGAN_g/n64s1/b1/4/moving_mean:0 (64,)              float32_ref
# [TL]   param  46: SRGAN_g/n64s1/b1/4/moving_variance:0 (64,)              float32_ref
# [TL]   param  47: SRGAN_g/n64s1/c2/4/kernel:0 (3, 3, 64, 64)     float32_ref
# [TL]   param  48: SRGAN_g/n64s1/b2/4/beta:0 (64,)              float32_ref
# [TL]   param  49: SRGAN_g/n64s1/b2/4/gamma:0 (64,)              float32_ref
# [TL]   param  50: SRGAN_g/n64s1/b2/4/moving_mean:0 (64,)              float32_ref
# [TL]   param  51: SRGAN_g/n64s1/b2/4/moving_variance:0 (64,)              float32_ref
# [TL]   param  52: SRGAN_g/n64s1/c1/5/kernel:0 (3, 3, 64, 64)     float32_ref
# [TL]   param  53: SRGAN_g/n64s1/b1/5/beta:0 (64,)              float32_ref
# [TL]   param  54: SRGAN_g/n64s1/b1/5/gamma:0 (64,)              float32_ref
# [TL]   param  55: SRGAN_g/n64s1/b1/5/moving_mean:0 (64,)              float32_ref
# [TL]   param  56: SRGAN_g/n64s1/b1/5/moving_variance:0 (64,)              float32_ref
# [TL]   param  57: SRGAN_g/n64s1/c2/5/kernel:0 (3, 3, 64, 64)     float32_ref
# [TL]   param  58: SRGAN_g/n64s1/b2/5/beta:0 (64,)              float32_ref
# [TL]   param  59: SRGAN_g/n64s1/b2/5/gamma:0 (64,)              float32_ref
# [TL]   param  60: SRGAN_g/n64s1/b2/5/moving_mean:0 (64,)              float32_ref
# [TL]   param  61: SRGAN_g/n64s1/b2/5/moving_variance:0 (64,)              float32_ref
# [TL]   param  62: SRGAN_g/n64s1/c1/6/kernel:0 (3, 3, 64, 64)     float32_ref
# [TL]   param  63: SRGAN_g/n64s1/b1/6/beta:0 (64,)              float32_ref
# [TL]   param  64: SRGAN_g/n64s1/b1/6/gamma:0 (64,)              float32_ref
# [TL]   param  65: SRGAN_g/n64s1/b1/6/moving_mean:0 (64,)              float32_ref
# [TL]   param  66: SRGAN_g/n64s1/b1/6/moving_variance:0 (64,)              float32_ref
# [TL]   param  67: SRGAN_g/n64s1/c2/6/kernel:0 (3, 3, 64, 64)     float32_ref
# [TL]   param  68: SRGAN_g/n64s1/b2/6/beta:0 (64,)              float32_ref
# [TL]   param  69: SRGAN_g/n64s1/b2/6/gamma:0 (64,)              float32_ref
# [TL]   param  70: SRGAN_g/n64s1/b2/6/moving_mean:0 (64,)              float32_ref
# [TL]   param  71: SRGAN_g/n64s1/b2/6/moving_variance:0 (64,)              float32_ref
# [TL]   param  72: SRGAN_g/n64s1/c1/7/kernel:0 (3, 3, 64, 64)     float32_ref
# [TL]   param  73: SRGAN_g/n64s1/b1/7/beta:0 (64,)              float32_ref
# [TL]   param  74: SRGAN_g/n64s1/b1/7/gamma:0 (64,)              float32_ref
# [TL]   param  75: SRGAN_g/n64s1/b1/7/moving_mean:0 (64,)              float32_ref
# [TL]   param  76: SRGAN_g/n64s1/b1/7/moving_variance:0 (64,)              float32_ref
# [TL]   param  77: SRGAN_g/n64s1/c2/7/kernel:0 (3, 3, 64, 64)     float32_ref
# [TL]   param  78: SRGAN_g/n64s1/b2/7/beta:0 (64,)              float32_ref
# [TL]   param  79: SRGAN_g/n64s1/b2/7/gamma:0 (64,)              float32_ref
# [TL]   param  80: SRGAN_g/n64s1/b2/7/moving_mean:0 (64,)              float32_ref
# [TL]   param  81: SRGAN_g/n64s1/b2/7/moving_variance:0 (64,)              float32_ref
# [TL]   param  82: SRGAN_g/n64s1/c1/8/kernel:0 (3, 3, 64, 64)     float32_ref
# [TL]   param  83: SRGAN_g/n64s1/b1/8/beta:0 (64,)              float32_ref
# [TL]   param  84: SRGAN_g/n64s1/b1/8/gamma:0 (64,)              float32_ref
# [TL]   param  85: SRGAN_g/n64s1/b1/8/moving_mean:0 (64,)              float32_ref
# [TL]   param  86: SRGAN_g/n64s1/b1/8/moving_variance:0 (64,)              float32_ref
# [TL]   param  87: SRGAN_g/n64s1/c2/8/kernel:0 (3, 3, 64, 64)     float32_ref
# [TL]   param  88: SRGAN_g/n64s1/b2/8/beta:0 (64,)              float32_ref
# [TL]   param  89: SRGAN_g/n64s1/b2/8/gamma:0 (64,)              float32_ref
# [TL]   param  90: SRGAN_g/n64s1/b2/8/moving_mean:0 (64,)              float32_ref
# [TL]   param  91: SRGAN_g/n64s1/b2/8/moving_variance:0 (64,)              float32_ref
# [TL]   param  92: SRGAN_g/n64s1/c1/9/kernel:0 (3, 3, 64, 64)     float32_ref
# [TL]   param  93: SRGAN_g/n64s1/b1/9/beta:0 (64,)              float32_ref
# [TL]   param  94: SRGAN_g/n64s1/b1/9/gamma:0 (64,)              float32_ref
# [TL]   param  95: SRGAN_g/n64s1/b1/9/moving_mean:0 (64,)              float32_ref
# [TL]   param  96: SRGAN_g/n64s1/b1/9/moving_variance:0 (64,)              float32_ref
# [TL]   param  97: SRGAN_g/n64s1/c2/9/kernel:0 (3, 3, 64, 64)     float32_ref
# [TL]   param  98: SRGAN_g/n64s1/b2/9/beta:0 (64,)              float32_ref
# [TL]   param  99: SRGAN_g/n64s1/b2/9/gamma:0 (64,)              float32_ref
# [TL]   param 100: SRGAN_g/n64s1/b2/9/moving_mean:0 (64,)              float32_ref
# [TL]   param 101: SRGAN_g/n64s1/b2/9/moving_variance:0 (64,)              float32_ref
# [TL]   param 102: SRGAN_g/n64s1/c1/10/kernel:0 (3, 3, 64, 64)     float32_ref
# [TL]   param 103: SRGAN_g/n64s1/b1/10/beta:0 (64,)              float32_ref
# [TL]   param 104: SRGAN_g/n64s1/b1/10/gamma:0 (64,)              float32_ref
# [TL]   param 105: SRGAN_g/n64s1/b1/10/moving_mean:0 (64,)              float32_ref
# [TL]   param 106: SRGAN_g/n64s1/b1/10/moving_variance:0 (64,)              float32_ref
# [TL]   param 107: SRGAN_g/n64s1/c2/10/kernel:0 (3, 3, 64, 64)     float32_ref
# [TL]   param 108: SRGAN_g/n64s1/b2/10/beta:0 (64,)              float32_ref
# [TL]   param 109: SRGAN_g/n64s1/b2/10/gamma:0 (64,)              float32_ref
# [TL]   param 110: SRGAN_g/n64s1/b2/10/moving_mean:0 (64,)              float32_ref
# [TL]   param 111: SRGAN_g/n64s1/b2/10/moving_variance:0 (64,)              float32_ref
# [TL]   param 112: SRGAN_g/n64s1/c1/11/kernel:0 (3, 3, 64, 64)     float32_ref
# [TL]   param 113: SRGAN_g/n64s1/b1/11/beta:0 (64,)              float32_ref
# [TL]   param 114: SRGAN_g/n64s1/b1/11/gamma:0 (64,)              float32_ref
# [TL]   param 115: SRGAN_g/n64s1/b1/11/moving_mean:0 (64,)              float32_ref
# [TL]   param 116: SRGAN_g/n64s1/b1/11/moving_variance:0 (64,)              float32_ref
# [TL]   param 117: SRGAN_g/n64s1/c2/11/kernel:0 (3, 3, 64, 64)     float32_ref
# [TL]   param 118: SRGAN_g/n64s1/b2/11/beta:0 (64,)              float32_ref
# [TL]   param 119: SRGAN_g/n64s1/b2/11/gamma:0 (64,)              float32_ref
# [TL]   param 120: SRGAN_g/n64s1/b2/11/moving_mean:0 (64,)              float32_ref
# [TL]   param 121: SRGAN_g/n64s1/b2/11/moving_variance:0 (64,)              float32_ref
# [TL]   param 122: SRGAN_g/n64s1/c1/12/kernel:0 (3, 3, 64, 64)     float32_ref
# [TL]   param 123: SRGAN_g/n64s1/b1/12/beta:0 (64,)              float32_ref
# [TL]   param 124: SRGAN_g/n64s1/b1/12/gamma:0 (64,)              float32_ref
# [TL]   param 125: SRGAN_g/n64s1/b1/12/moving_mean:0 (64,)              float32_ref
# [TL]   param 126: SRGAN_g/n64s1/b1/12/moving_variance:0 (64,)              float32_ref
# [TL]   param 127: SRGAN_g/n64s1/c2/12/kernel:0 (3, 3, 64, 64)     float32_ref
# [TL]   param 128: SRGAN_g/n64s1/b2/12/beta:0 (64,)              float32_ref
# [TL]   param 129: SRGAN_g/n64s1/b2/12/gamma:0 (64,)              float32_ref
# [TL]   param 130: SRGAN_g/n64s1/b2/12/moving_mean:0 (64,)              float32_ref
# [TL]   param 131: SRGAN_g/n64s1/b2/12/moving_variance:0 (64,)              float32_ref
# [TL]   param 132: SRGAN_g/n64s1/c1/13/kernel:0 (3, 3, 64, 64)     float32_ref
# [TL]   param 133: SRGAN_g/n64s1/b1/13/beta:0 (64,)              float32_ref
# [TL]   param 134: SRGAN_g/n64s1/b1/13/gamma:0 (64,)              float32_ref
# [TL]   param 135: SRGAN_g/n64s1/b1/13/moving_mean:0 (64,)              float32_ref
# [TL]   param 136: SRGAN_g/n64s1/b1/13/moving_variance:0 (64,)              float32_ref
# [TL]   param 137: SRGAN_g/n64s1/c2/13/kernel:0 (3, 3, 64, 64)     float32_ref
# [TL]   param 138: SRGAN_g/n64s1/b2/13/beta:0 (64,)              float32_ref
# [TL]   param 139: SRGAN_g/n64s1/b2/13/gamma:0 (64,)              float32_ref
# [TL]   param 140: SRGAN_g/n64s1/b2/13/moving_mean:0 (64,)              float32_ref
# [TL]   param 141: SRGAN_g/n64s1/b2/13/moving_variance:0 (64,)              float32_ref
# [TL]   param 142: SRGAN_g/n64s1/c1/14/kernel:0 (3, 3, 64, 64)     float32_ref
# [TL]   param 143: SRGAN_g/n64s1/b1/14/beta:0 (64,)              float32_ref
# [TL]   param 144: SRGAN_g/n64s1/b1/14/gamma:0 (64,)              float32_ref
# [TL]   param 145: SRGAN_g/n64s1/b1/14/moving_mean:0 (64,)              float32_ref
# [TL]   param 146: SRGAN_g/n64s1/b1/14/moving_variance:0 (64,)              float32_ref
# [TL]   param 147: SRGAN_g/n64s1/c2/14/kernel:0 (3, 3, 64, 64)     float32_ref
# [TL]   param 148: SRGAN_g/n64s1/b2/14/beta:0 (64,)              float32_ref
# [TL]   param 149: SRGAN_g/n64s1/b2/14/gamma:0 (64,)              float32_ref
# [TL]   param 150: SRGAN_g/n64s1/b2/14/moving_mean:0 (64,)              float32_ref
# [TL]   param 151: SRGAN_g/n64s1/b2/14/moving_variance:0 (64,)              float32_ref
# [TL]   param 152: SRGAN_g/n64s1/c1/15/kernel:0 (3, 3, 64, 64)     float32_ref
# [TL]   param 153: SRGAN_g/n64s1/b1/15/beta:0 (64,)              float32_ref
# [TL]   param 154: SRGAN_g/n64s1/b1/15/gamma:0 (64,)              float32_ref
# [TL]   param 155: SRGAN_g/n64s1/b1/15/moving_mean:0 (64,)              float32_ref
# [TL]   param 156: SRGAN_g/n64s1/b1/15/moving_variance:0 (64,)              float32_ref
# [TL]   param 157: SRGAN_g/n64s1/c2/15/kernel:0 (3, 3, 64, 64)     float32_ref
# [TL]   param 158: SRGAN_g/n64s1/b2/15/beta:0 (64,)              float32_ref
# [TL]   param 159: SRGAN_g/n64s1/b2/15/gamma:0 (64,)              float32_ref
# [TL]   param 160: SRGAN_g/n64s1/b2/15/moving_mean:0 (64,)              float32_ref
# [TL]   param 161: SRGAN_g/n64s1/b2/15/moving_variance:0 (64,)              float32_ref
# [TL]   param 162: SRGAN_g/n64s1/c/m/kernel:0 (3, 3, 64, 64)     float32_ref
# [TL]   param 163: SRGAN_g/n64s1/b/m/beta:0 (64,)              float32_ref
# [TL]   param 164: SRGAN_g/n64s1/b/m/gamma:0 (64,)              float32_ref
# [TL]   param 165: SRGAN_g/n64s1/b/m/moving_mean:0 (64,)              float32_ref
# [TL]   param 166: SRGAN_g/n64s1/b/m/moving_variance:0 (64,)              float32_ref
# [TL]   param 167: SRGAN_g/n256s1/1/kernel:0 (3, 3, 64, 256)    float32_ref
# [TL]   param 168: SRGAN_g/n256s1/1/bias:0 (256,)             float32_ref
# [TL]   param 169: SRGAN_g/n256s1/2/kernel:0 (3, 3, 64, 256)    float32_ref
# [TL]   param 170: SRGAN_g/n256s1/2/bias:0 (256,)             float32_ref
# [TL]   param 171: SRGAN_g/out/kernel:0 (1, 1, 64, 3)      float32_ref
# [TL]   param 172: SRGAN_g/out/bias:0   (3,)               float32_ref
# [TL]   num of params: 1522371
# [TL]   layer   0: t_image_input_to_SRGAN_generator:0 (25, 56, 56, 3)    float32
# [TL]   layer   1: SRGAN_g/n64s1/c/Relu:0 (25, 56, 56, 64)    float32
# [TL]   layer   2: SRGAN_g/n64s1/c1/0/Conv2D:0 (25, 56, 56, 64)    float32
# [TL]   layer   3: SRGAN_g/n64s1/b1/0/Relu:0 (25, 56, 56, 64)    float32
# [TL]   layer   4: SRGAN_g/n64s1/c2/0/Conv2D:0 (25, 56, 56, 64)    float32
# [TL]   layer   5: SRGAN_g/n64s1/b2/0/batchnorm/Add_1:0 (25, 56, 56, 64)    float32
# [TL]   layer   6: SRGAN_g/b_residual_add/0:0 (25, 56, 56, 64)    float32
# [TL]   layer   7: SRGAN_g/n64s1/c1/1/Conv2D:0 (25, 56, 56, 64)    float32
# [TL]   layer   8: SRGAN_g/n64s1/b1/1/Relu:0 (25, 56, 56, 64)    float32
# [TL]   layer   9: SRGAN_g/n64s1/c2/1/Conv2D:0 (25, 56, 56, 64)    float32
# [TL]   layer  10: SRGAN_g/n64s1/b2/1/batchnorm/Add_1:0 (25, 56, 56, 64)    float32
# [TL]   layer  11: SRGAN_g/b_residual_add/1:0 (25, 56, 56, 64)    float32
# [TL]   layer  12: SRGAN_g/n64s1/c1/2/Conv2D:0 (25, 56, 56, 64)    float32
# [TL]   layer  13: SRGAN_g/n64s1/b1/2/Relu:0 (25, 56, 56, 64)    float32
# [TL]   layer  14: SRGAN_g/n64s1/c2/2/Conv2D:0 (25, 56, 56, 64)    float32
# [TL]   layer  15: SRGAN_g/n64s1/b2/2/batchnorm/Add_1:0 (25, 56, 56, 64)    float32
# [TL]   layer  16: SRGAN_g/b_residual_add/2:0 (25, 56, 56, 64)    float32
# [TL]   layer  17: SRGAN_g/n64s1/c1/3/Conv2D:0 (25, 56, 56, 64)    float32
# [TL]   layer  18: SRGAN_g/n64s1/b1/3/Relu:0 (25, 56, 56, 64)    float32
# [TL]   layer  19: SRGAN_g/n64s1/c2/3/Conv2D:0 (25, 56, 56, 64)    float32
# [TL]   layer  20: SRGAN_g/n64s1/b2/3/batchnorm/Add_1:0 (25, 56, 56, 64)    float32
# [TL]   layer  21: SRGAN_g/b_residual_add/3:0 (25, 56, 56, 64)    float32
# [TL]   layer  22: SRGAN_g/n64s1/c1/4/Conv2D:0 (25, 56, 56, 64)    float32
# [TL]   layer  23: SRGAN_g/n64s1/b1/4/Relu:0 (25, 56, 56, 64)    float32
# [TL]   layer  24: SRGAN_g/n64s1/c2/4/Conv2D:0 (25, 56, 56, 64)    float32
# [TL]   layer  25: SRGAN_g/n64s1/b2/4/batchnorm/Add_1:0 (25, 56, 56, 64)    float32
# [TL]   layer  26: SRGAN_g/b_residual_add/4:0 (25, 56, 56, 64)    float32
# [TL]   layer  27: SRGAN_g/n64s1/c1/5/Conv2D:0 (25, 56, 56, 64)    float32
# [TL]   layer  28: SRGAN_g/n64s1/b1/5/Relu:0 (25, 56, 56, 64)    float32
# [TL]   layer  29: SRGAN_g/n64s1/c2/5/Conv2D:0 (25, 56, 56, 64)    float32
# [TL]   layer  30: SRGAN_g/n64s1/b2/5/batchnorm/Add_1:0 (25, 56, 56, 64)    float32
# [TL]   layer  31: SRGAN_g/b_residual_add/5:0 (25, 56, 56, 64)    float32
# [TL]   layer  32: SRGAN_g/n64s1/c1/6/Conv2D:0 (25, 56, 56, 64)    float32
# [TL]   layer  33: SRGAN_g/n64s1/b1/6/Relu:0 (25, 56, 56, 64)    float32
# [TL]   layer  34: SRGAN_g/n64s1/c2/6/Conv2D:0 (25, 56, 56, 64)    float32
# [TL]   layer  35: SRGAN_g/n64s1/b2/6/batchnorm/Add_1:0 (25, 56, 56, 64)    float32
# [TL]   layer  36: SRGAN_g/b_residual_add/6:0 (25, 56, 56, 64)    float32
# [TL]   layer  37: SRGAN_g/n64s1/c1/7/Conv2D:0 (25, 56, 56, 64)    float32
# [TL]   layer  38: SRGAN_g/n64s1/b1/7/Relu:0 (25, 56, 56, 64)    float32
# [TL]   layer  39: SRGAN_g/n64s1/c2/7/Conv2D:0 (25, 56, 56, 64)    float32
# [TL]   layer  40: SRGAN_g/n64s1/b2/7/batchnorm/Add_1:0 (25, 56, 56, 64)    float32
# [TL]   layer  41: SRGAN_g/b_residual_add/7:0 (25, 56, 56, 64)    float32
# [TL]   layer  42: SRGAN_g/n64s1/c1/8/Conv2D:0 (25, 56, 56, 64)    float32
# [TL]   layer  43: SRGAN_g/n64s1/b1/8/Relu:0 (25, 56, 56, 64)    float32
# [TL]   layer  44: SRGAN_g/n64s1/c2/8/Conv2D:0 (25, 56, 56, 64)    float32
# [TL]   layer  45: SRGAN_g/n64s1/b2/8/batchnorm/Add_1:0 (25, 56, 56, 64)    float32
# [TL]   layer  46: SRGAN_g/b_residual_add/8:0 (25, 56, 56, 64)    float32
# [TL]   layer  47: SRGAN_g/n64s1/c1/9/Conv2D:0 (25, 56, 56, 64)    float32
# [TL]   layer  48: SRGAN_g/n64s1/b1/9/Relu:0 (25, 56, 56, 64)    float32
# [TL]   layer  49: SRGAN_g/n64s1/c2/9/Conv2D:0 (25, 56, 56, 64)    float32
# [TL]   layer  50: SRGAN_g/n64s1/b2/9/batchnorm/Add_1:0 (25, 56, 56, 64)    float32
# [TL]   layer  51: SRGAN_g/b_residual_add/9:0 (25, 56, 56, 64)    float32
# [TL]   layer  52: SRGAN_g/n64s1/c1/10/Conv2D:0 (25, 56, 56, 64)    float32
# [TL]   layer  53: SRGAN_g/n64s1/b1/10/Relu:0 (25, 56, 56, 64)    float32
# [TL]   layer  54: SRGAN_g/n64s1/c2/10/Conv2D:0 (25, 56, 56, 64)    float32
# [TL]   layer  55: SRGAN_g/n64s1/b2/10/batchnorm/Add_1:0 (25, 56, 56, 64)    float32
# [TL]   layer  56: SRGAN_g/b_residual_add/10:0 (25, 56, 56, 64)    float32
# [TL]   layer  57: SRGAN_g/n64s1/c1/11/Conv2D:0 (25, 56, 56, 64)    float32
# [TL]   layer  58: SRGAN_g/n64s1/b1/11/Relu:0 (25, 56, 56, 64)    float32
# [TL]   layer  59: SRGAN_g/n64s1/c2/11/Conv2D:0 (25, 56, 56, 64)    float32
# [TL]   layer  60: SRGAN_g/n64s1/b2/11/batchnorm/Add_1:0 (25, 56, 56, 64)    float32
# [TL]   layer  61: SRGAN_g/b_residual_add/11:0 (25, 56, 56, 64)    float32
# [TL]   layer  62: SRGAN_g/n64s1/c1/12/Conv2D:0 (25, 56, 56, 64)    float32
# [TL]   layer  63: SRGAN_g/n64s1/b1/12/Relu:0 (25, 56, 56, 64)    float32
# [TL]   layer  64: SRGAN_g/n64s1/c2/12/Conv2D:0 (25, 56, 56, 64)    float32
# [TL]   layer  65: SRGAN_g/n64s1/b2/12/batchnorm/Add_1:0 (25, 56, 56, 64)    float32
# [TL]   layer  66: SRGAN_g/b_residual_add/12:0 (25, 56, 56, 64)    float32
# [TL]   layer  67: SRGAN_g/n64s1/c1/13/Conv2D:0 (25, 56, 56, 64)    float32
# [TL]   layer  68: SRGAN_g/n64s1/b1/13/Relu:0 (25, 56, 56, 64)    float32
# [TL]   layer  69: SRGAN_g/n64s1/c2/13/Conv2D:0 (25, 56, 56, 64)    float32
# [TL]   layer  70: SRGAN_g/n64s1/b2/13/batchnorm/Add_1:0 (25, 56, 56, 64)    float32
# [TL]   layer  71: SRGAN_g/b_residual_add/13:0 (25, 56, 56, 64)    float32
# [TL]   layer  72: SRGAN_g/n64s1/c1/14/Conv2D:0 (25, 56, 56, 64)    float32
# [TL]   layer  73: SRGAN_g/n64s1/b1/14/Relu:0 (25, 56, 56, 64)    float32
# [TL]   layer  74: SRGAN_g/n64s1/c2/14/Conv2D:0 (25, 56, 56, 64)    float32
# [TL]   layer  75: SRGAN_g/n64s1/b2/14/batchnorm/Add_1:0 (25, 56, 56, 64)    float32
# [TL]   layer  76: SRGAN_g/b_residual_add/14:0 (25, 56, 56, 64)    float32
# [TL]   layer  77: SRGAN_g/n64s1/c1/15/Conv2D:0 (25, 56, 56, 64)    float32
# [TL]   layer  78: SRGAN_g/n64s1/b1/15/Relu:0 (25, 56, 56, 64)    float32
# [TL]   layer  79: SRGAN_g/n64s1/c2/15/Conv2D:0 (25, 56, 56, 64)    float32
# [TL]   layer  80: SRGAN_g/n64s1/b2/15/batchnorm/Add_1:0 (25, 56, 56, 64)    float32
# [TL]   layer  81: SRGAN_g/b_residual_add/15:0 (25, 56, 56, 64)    float32
# [TL]   layer  82: SRGAN_g/n64s1/c/m/Conv2D:0 (25, 56, 56, 64)    float32
# [TL]   layer  83: SRGAN_g/n64s1/b/m/batchnorm/Add_1:0 (25, 56, 56, 64)    float32
# [TL]   layer  84: SRGAN_g/add3:0       (25, 56, 56, 64)    float32
# [TL]   layer  85: SRGAN_g/n256s1/1/BiasAdd:0 (25, 56, 56, 256)    float32
# [TL]   layer  86: SRGAN_g/pixelshufflerx2/1/Relu:0 (25, 112, 112, 64)    float32
# [TL]   layer  87: SRGAN_g/n256s1/2/BiasAdd:0 (25, 112, 112, 256)    float32
# [TL]   layer  88: SRGAN_g/pixelshufflerx2/2/Relu:0 (25, 224, 224, 64)    float32
# [TL]   layer  89: SRGAN_g/out/Tanh:0   (25, 224, 224, 3)    float32
# [TL]   param   0: SRGAN_d/h0/c/kernel:0 (4, 4, 3, 64)      float32_ref
# [TL]   param   1: SRGAN_d/h0/c/bias:0  (64,)              float32_ref
# [TL]   param   2: SRGAN_d/h1/c/kernel:0 (4, 4, 64, 128)    float32_ref
# [TL]   param   3: SRGAN_d/h1/bn/beta:0 (128,)             float32_ref
# [TL]   param   4: SRGAN_d/h1/bn/gamma:0 (128,)             float32_ref
# [TL]   param   5: SRGAN_d/h1/bn/moving_mean:0 (128,)             float32_ref
# [TL]   param   6: SRGAN_d/h1/bn/moving_variance:0 (128,)             float32_ref
# [TL]   param   7: SRGAN_d/h2/c/kernel:0 (4, 4, 128, 256)    float32_ref
# [TL]   param   8: SRGAN_d/h2/bn/beta:0 (256,)             float32_ref
# [TL]   param   9: SRGAN_d/h2/bn/gamma:0 (256,)             float32_ref
# [TL]   param  10: SRGAN_d/h2/bn/moving_mean:0 (256,)             float32_ref
# [TL]   param  11: SRGAN_d/h2/bn/moving_variance:0 (256,)             float32_ref
# [TL]   param  12: SRGAN_d/h3/c/kernel:0 (4, 4, 256, 512)    float32_ref
# [TL]   param  13: SRGAN_d/h3/bn/beta:0 (512,)             float32_ref
# [TL]   param  14: SRGAN_d/h3/bn/gamma:0 (512,)             float32_ref
# [TL]   param  15: SRGAN_d/h3/bn/moving_mean:0 (512,)             float32_ref
# [TL]   param  16: SRGAN_d/h3/bn/moving_variance:0 (512,)             float32_ref
# [TL]   param  17: SRGAN_d/h4/c/kernel:0 (4, 4, 512, 1024)    float32_ref
# [TL]   param  18: SRGAN_d/h4/bn/beta:0 (1024,)            float32_ref
# [TL]   param  19: SRGAN_d/h4/bn/gamma:0 (1024,)            float32_ref
# [TL]   param  20: SRGAN_d/h4/bn/moving_mean:0 (1024,)            float32_ref
# [TL]   param  21: SRGAN_d/h4/bn/moving_variance:0 (1024,)            float32_ref
# [TL]   param  22: SRGAN_d/h5/c/kernel:0 (4, 4, 1024, 2048)    float32_ref
# [TL]   param  23: SRGAN_d/h5/bn/beta:0 (2048,)            float32_ref
# [TL]   param  24: SRGAN_d/h5/bn/gamma:0 (2048,)            float32_ref
# [TL]   param  25: SRGAN_d/h5/bn/moving_mean:0 (2048,)            float32_ref
# [TL]   param  26: SRGAN_d/h5/bn/moving_variance:0 (2048,)            float32_ref
# [TL]   param  27: SRGAN_d/h6/c/kernel:0 (1, 1, 2048, 1024)    float32_ref
# [TL]   param  28: SRGAN_d/h6/bn/beta:0 (1024,)            float32_ref
# [TL]   param  29: SRGAN_d/h6/bn/gamma:0 (1024,)            float32_ref
# [TL]   param  30: SRGAN_d/h6/bn/moving_mean:0 (1024,)            float32_ref
# [TL]   param  31: SRGAN_d/h6/bn/moving_variance:0 (1024,)            float32_ref
# [TL]   param  32: SRGAN_d/h7/c/kernel:0 (1, 1, 1024, 512)    float32_ref
# [TL]   param  33: SRGAN_d/h7/bn/beta:0 (512,)             float32_ref
# [TL]   param  34: SRGAN_d/h7/bn/gamma:0 (512,)             float32_ref
# [TL]   param  35: SRGAN_d/h7/bn/moving_mean:0 (512,)             float32_ref
# [TL]   param  36: SRGAN_d/h7/bn/moving_variance:0 (512,)             float32_ref
# [TL]   param  37: SRGAN_d/res/c/kernel:0 (1, 1, 512, 128)    float32_ref
# [TL]   param  38: SRGAN_d/res/bn/beta:0 (128,)             float32_ref
# [TL]   param  39: SRGAN_d/res/bn/gamma:0 (128,)             float32_ref
# [TL]   param  40: SRGAN_d/res/bn/moving_mean:0 (128,)             float32_ref
# [TL]   param  41: SRGAN_d/res/bn/moving_variance:0 (128,)             float32_ref
# [TL]   param  42: SRGAN_d/res/c2/kernel:0 (3, 3, 128, 128)    float32_ref
# [TL]   param  43: SRGAN_d/res/bn2/beta:0 (128,)             float32_ref
# [TL]   param  44: SRGAN_d/res/bn2/gamma:0 (128,)             float32_ref
# [TL]   param  45: SRGAN_d/res/bn2/moving_mean:0 (128,)             float32_ref
# [TL]   param  46: SRGAN_d/res/bn2/moving_variance:0 (128,)             float32_ref
# [TL]   param  47: SRGAN_d/res/c3/kernel:0 (3, 3, 128, 512)    float32_ref
# [TL]   param  48: SRGAN_d/res/bn3/beta:0 (512,)             float32_ref
# [TL]   param  49: SRGAN_d/res/bn3/gamma:0 (512,)             float32_ref
# [TL]   param  50: SRGAN_d/res/bn3/moving_mean:0 (512,)             float32_ref
# [TL]   param  51: SRGAN_d/res/bn3/moving_variance:0 (512,)             float32_ref
# [TL]   param  52: SRGAN_d/ho/dense/W:0 (8192, 1)          float32_ref
# [TL]   param  53: SRGAN_d/ho/dense/b:0 (1,)               float32_ref
# [TL]   num of params: 48156225
# [TL]   layer   0: t_target_image:0     (25, 224, 224, 3)    float32
# [TL]   layer   1: SRGAN_d/h0/c/leaky_relu:0 (25, 112, 112, 64)    float32
# [TL]   layer   2: SRGAN_d/h1/c/Conv2D:0 (25, 56, 56, 128)    float32
# [TL]   layer   3: SRGAN_d/h1/bn/leaky_relu:0 (25, 56, 56, 128)    float32
# [TL]   layer   4: SRGAN_d/h2/c/Conv2D:0 (25, 28, 28, 256)    float32
# [TL]   layer   5: SRGAN_d/h2/bn/leaky_relu:0 (25, 28, 28, 256)    float32
# [TL]   layer   6: SRGAN_d/h3/c/Conv2D:0 (25, 14, 14, 512)    float32
# [TL]   layer   7: SRGAN_d/h3/bn/leaky_relu:0 (25, 14, 14, 512)    float32
# [TL]   layer   8: SRGAN_d/h4/c/Conv2D:0 (25, 7, 7, 1024)    float32
# [TL]   layer   9: SRGAN_d/h4/bn/leaky_relu:0 (25, 7, 7, 1024)    float32
# [TL]   layer  10: SRGAN_d/h5/c/Conv2D:0 (25, 4, 4, 2048)    float32
# [TL]   layer  11: SRGAN_d/h5/bn/leaky_relu:0 (25, 4, 4, 2048)    float32
# [TL]   layer  12: SRGAN_d/h6/c/Conv2D:0 (25, 4, 4, 1024)    float32
# [TL]   layer  13: SRGAN_d/h6/bn/leaky_relu:0 (25, 4, 4, 1024)    float32
# [TL]   layer  14: SRGAN_d/h7/c/Conv2D:0 (25, 4, 4, 512)    float32
# [TL]   layer  15: SRGAN_d/h7/bn/batchnorm/Add_1:0 (25, 4, 4, 512)    float32
# [TL]   layer  16: SRGAN_d/res/c/Conv2D:0 (25, 4, 4, 128)    float32
# [TL]   layer  17: SRGAN_d/res/bn/leaky_relu:0 (25, 4, 4, 128)    float32
# [TL]   layer  18: SRGAN_d/res/c2/Conv2D:0 (25, 4, 4, 128)    float32
# [TL]   layer  19: SRGAN_d/res/bn2/leaky_relu:0 (25, 4, 4, 128)    float32
# [TL]   layer  20: SRGAN_d/res/c3/Conv2D:0 (25, 4, 4, 512)    float32
# [TL]   layer  21: SRGAN_d/res/bn3/batchnorm/Add_1:0 (25, 4, 4, 512)    float32
# [TL]   layer  22: SRGAN_d/res/add:0    (25, 4, 4, 512)    float32
# [TL]   layer  23: SRGAN_d/ho/flatten:0 (25, 8192)         float32
# [TL]   layer  24: SRGAN_d/ho/dense/bias_add:0 (25, 1)            float32

# %%
t_target_image_224 = tf.image.resize_images(t_target_image, size=[224, 224], method=0,align_corners=False)

# %%
t_predict_image_224 = tf.image.resize_images(net_g.outputs, size=[224, 224], method=0, align_corners=False)

# %%
net_vgg, vgg_target_emb = Vgg19_simple_api((t_target_image_224 + 1) / 2, reuse=False)
_, vgg_predict_emb = Vgg19_simple_api((t_predict_image_224 + 1) / 2, reuse=True)
# Out:
# build model started
# [TL] InputLayer  VGG19/input: (25, 224, 224, 3)
# [TL] Conv2d VGG19/conv1_1: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: relu
# [TL] Conv2d VGG19/conv1_2: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: relu
# [TL] MaxPool2d VGG19/pool1: filter_size: (2, 2) strides: (2, 2) padding: SAME
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/srgan/lib/python3.7/site-packages/tensorlayer/layers/pooling.py:200: max_pooling2d (from tensorflow.python.layers.pooling) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.max_pooling2d instead.
# [TL] Conv2d VGG19/conv2_1: n_filter: 128 filter_size: (3, 3) strides: (1, 1) pad: SAME act: relu
# [TL] Conv2d VGG19/conv2_2: n_filter: 128 filter_size: (3, 3) strides: (1, 1) pad: SAME act: relu
# [TL] MaxPool2d VGG19/pool2: filter_size: (2, 2) strides: (2, 2) padding: SAME
# [TL] Conv2d VGG19/conv3_1: n_filter: 256 filter_size: (3, 3) strides: (1, 1) pad: SAME act: relu
# [TL] Conv2d VGG19/conv3_2: n_filter: 256 filter_size: (3, 3) strides: (1, 1) pad: SAME act: relu
# [TL] Conv2d VGG19/conv3_3: n_filter: 256 filter_size: (3, 3) strides: (1, 1) pad: SAME act: relu
# [TL] Conv2d VGG19/conv3_4: n_filter: 256 filter_size: (3, 3) strides: (1, 1) pad: SAME act: relu
# [TL] MaxPool2d VGG19/pool3: filter_size: (2, 2) strides: (2, 2) padding: SAME
# [TL] Conv2d VGG19/conv4_1: n_filter: 512 filter_size: (3, 3) strides: (1, 1) pad: SAME act: relu
# [TL] Conv2d VGG19/conv4_2: n_filter: 512 filter_size: (3, 3) strides: (1, 1) pad: SAME act: relu
# [TL] Conv2d VGG19/conv4_3: n_filter: 512 filter_size: (3, 3) strides: (1, 1) pad: SAME act: relu
# [TL] Conv2d VGG19/conv4_4: n_filter: 512 filter_size: (3, 3) strides: (1, 1) pad: SAME act: relu
# [TL] MaxPool2d VGG19/pool4: filter_size: (2, 2) strides: (2, 2) padding: SAME
# [TL] Conv2d VGG19/conv5_1: n_filter: 512 filter_size: (3, 3) strides: (1, 1) pad: SAME act: relu
# [TL] Conv2d VGG19/conv5_2: n_filter: 512 filter_size: (3, 3) strides: (1, 1) pad: SAME act: relu
# [TL] Conv2d VGG19/conv5_3: n_filter: 512 filter_size: (3, 3) strides: (1, 1) pad: SAME act: relu
# [TL] Conv2d VGG19/conv5_4: n_filter: 512 filter_size: (3, 3) strides: (1, 1) pad: SAME act: relu
# [TL] MaxPool2d VGG19/pool5: filter_size: (2, 2) strides: (2, 2) padding: SAME
# [TL] FlattenLayer VGG19/flatten: 25088
# [TL] DenseLayer  VGG19/fc6: 4096 relu
# [TL] DenseLayer  VGG19/fc7: 4096 relu
# [TL] DenseLayer  VGG19/fc8: 1000 No Activation
# build model finished: 2.655631s
# build model started
# [TL] InputLayer  VGG19/input: (25, 224, 224, 3)
# [TL] Conv2d VGG19/conv1_1: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: relu
# [TL] Conv2d VGG19/conv1_2: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: relu
# [TL] MaxPool2d VGG19/pool1: filter_size: (2, 2) strides: (2, 2) padding: SAME
# [TL] Conv2d VGG19/conv2_1: n_filter: 128 filter_size: (3, 3) strides: (1, 1) pad: SAME act: relu
# [TL] Conv2d VGG19/conv2_2: n_filter: 128 filter_size: (3, 3) strides: (1, 1) pad: SAME act: relu
# [TL] MaxPool2d VGG19/pool2: filter_size: (2, 2) strides: (2, 2) padding: SAME
# [TL] Conv2d VGG19/conv3_1: n_filter: 256 filter_size: (3, 3) strides: (1, 1) pad: SAME act: relu
# [TL] Conv2d VGG19/conv3_2: n_filter: 256 filter_size: (3, 3) strides: (1, 1) pad: SAME act: relu
# [TL] Conv2d VGG19/conv3_3: n_filter: 256 filter_size: (3, 3) strides: (1, 1) pad: SAME act: relu
# [TL] Conv2d VGG19/conv3_4: n_filter: 256 filter_size: (3, 3) strides: (1, 1) pad: SAME act: relu
# [TL] MaxPool2d VGG19/pool3: filter_size: (2, 2) strides: (2, 2) padding: SAME
# [TL] Conv2d VGG19/conv4_1: n_filter: 512 filter_size: (3, 3) strides: (1, 1) pad: SAME act: relu
# [TL] Conv2d VGG19/conv4_2: n_filter: 512 filter_size: (3, 3) strides: (1, 1) pad: SAME act: relu
# [TL] Conv2d VGG19/conv4_3: n_filter: 512 filter_size: (3, 3) strides: (1, 1) pad: SAME act: relu
# [TL] Conv2d VGG19/conv4_4: n_filter: 512 filter_size: (3, 3) strides: (1, 1) pad: SAME act: relu
# [TL] MaxPool2d VGG19/pool4: filter_size: (2, 2) strides: (2, 2) padding: SAME
# [TL] Conv2d VGG19/conv5_1: n_filter: 512 filter_size: (3, 3) strides: (1, 1) pad: SAME act: relu
# [TL] Conv2d VGG19/conv5_2: n_filter: 512 filter_size: (3, 3) strides: (1, 1) pad: SAME act: relu
# [TL] Conv2d VGG19/conv5_3: n_filter: 512 filter_size: (3, 3) strides: (1, 1) pad: SAME act: relu
# [TL] Conv2d VGG19/conv5_4: n_filter: 512 filter_size: (3, 3) strides: (1, 1) pad: SAME act: relu
# [TL] MaxPool2d VGG19/pool5: filter_size: (2, 2) strides: (2, 2) padding: SAME
# [TL] FlattenLayer VGG19/flatten: 25088
# [TL] DenseLayer  VGG19/fc6: 4096 relu
# [TL] DenseLayer  VGG19/fc7: 4096 relu
# [TL] DenseLayer  VGG19/fc8: 1000 No Activation
# build model finished: 2.452853s

# %%
## test inference
net_g_test = SRGAN_g(t_image, is_train=False, reuse=True)
# Out:
# [TL] InputLayer  SRGAN_g/in: (25, 56, 56, 3)
# [TL] Conv2d SRGAN_g/n64s1/c: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: relu
# [TL] Conv2d SRGAN_g/n64s1/c1/0: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b1/0: decay: 0.900000 epsilon: 0.000010 act: relu is_train: False
# [TL] Conv2d SRGAN_g/n64s1/c2/0: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b2/0: decay: 0.900000 epsilon: 0.000010 act: No Activation is_train: False
# [TL] ElementwiseLayer SRGAN_g/b_residual_add/0: size: (25, 56, 56, 64) fn: add
# [TL] Conv2d SRGAN_g/n64s1/c1/1: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b1/1: decay: 0.900000 epsilon: 0.000010 act: relu is_train: False
# [TL] Conv2d SRGAN_g/n64s1/c2/1: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b2/1: decay: 0.900000 epsilon: 0.000010 act: No Activation is_train: False
# [TL] ElementwiseLayer SRGAN_g/b_residual_add/1: size: (25, 56, 56, 64) fn: add
# [TL] Conv2d SRGAN_g/n64s1/c1/2: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b1/2: decay: 0.900000 epsilon: 0.000010 act: relu is_train: False
# [TL] Conv2d SRGAN_g/n64s1/c2/2: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b2/2: decay: 0.900000 epsilon: 0.000010 act: No Activation is_train: False
# [TL] ElementwiseLayer SRGAN_g/b_residual_add/2: size: (25, 56, 56, 64) fn: add
# [TL] Conv2d SRGAN_g/n64s1/c1/3: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b1/3: decay: 0.900000 epsilon: 0.000010 act: relu is_train: False
# [TL] Conv2d SRGAN_g/n64s1/c2/3: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b2/3: decay: 0.900000 epsilon: 0.000010 act: No Activation is_train: False
# [TL] ElementwiseLayer SRGAN_g/b_residual_add/3: size: (25, 56, 56, 64) fn: add
# [TL] Conv2d SRGAN_g/n64s1/c1/4: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b1/4: decay: 0.900000 epsilon: 0.000010 act: relu is_train: False
# [TL] Conv2d SRGAN_g/n64s1/c2/4: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b2/4: decay: 0.900000 epsilon: 0.000010 act: No Activation is_train: False
# [TL] ElementwiseLayer SRGAN_g/b_residual_add/4: size: (25, 56, 56, 64) fn: add
# [TL] Conv2d SRGAN_g/n64s1/c1/5: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b1/5: decay: 0.900000 epsilon: 0.000010 act: relu is_train: False
# [TL] Conv2d SRGAN_g/n64s1/c2/5: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b2/5: decay: 0.900000 epsilon: 0.000010 act: No Activation is_train: False
# [TL] ElementwiseLayer SRGAN_g/b_residual_add/5: size: (25, 56, 56, 64) fn: add
# [TL] Conv2d SRGAN_g/n64s1/c1/6: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b1/6: decay: 0.900000 epsilon: 0.000010 act: relu is_train: False
# [TL] Conv2d SRGAN_g/n64s1/c2/6: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b2/6: decay: 0.900000 epsilon: 0.000010 act: No Activation is_train: False
# [TL] ElementwiseLayer SRGAN_g/b_residual_add/6: size: (25, 56, 56, 64) fn: add
# [TL] Conv2d SRGAN_g/n64s1/c1/7: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b1/7: decay: 0.900000 epsilon: 0.000010 act: relu is_train: False
# [TL] Conv2d SRGAN_g/n64s1/c2/7: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b2/7: decay: 0.900000 epsilon: 0.000010 act: No Activation is_train: False
# [TL] ElementwiseLayer SRGAN_g/b_residual_add/7: size: (25, 56, 56, 64) fn: add
# [TL] Conv2d SRGAN_g/n64s1/c1/8: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b1/8: decay: 0.900000 epsilon: 0.000010 act: relu is_train: False
# [TL] Conv2d SRGAN_g/n64s1/c2/8: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b2/8: decay: 0.900000 epsilon: 0.000010 act: No Activation is_train: False
# [TL] ElementwiseLayer SRGAN_g/b_residual_add/8: size: (25, 56, 56, 64) fn: add
# [TL] Conv2d SRGAN_g/n64s1/c1/9: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b1/9: decay: 0.900000 epsilon: 0.000010 act: relu is_train: False
# [TL] Conv2d SRGAN_g/n64s1/c2/9: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b2/9: decay: 0.900000 epsilon: 0.000010 act: No Activation is_train: False
# [TL] ElementwiseLayer SRGAN_g/b_residual_add/9: size: (25, 56, 56, 64) fn: add
# [TL] Conv2d SRGAN_g/n64s1/c1/10: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b1/10: decay: 0.900000 epsilon: 0.000010 act: relu is_train: False
# [TL] Conv2d SRGAN_g/n64s1/c2/10: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b2/10: decay: 0.900000 epsilon: 0.000010 act: No Activation is_train: False
# [TL] ElementwiseLayer SRGAN_g/b_residual_add/10: size: (25, 56, 56, 64) fn: add
# [TL] Conv2d SRGAN_g/n64s1/c1/11: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b1/11: decay: 0.900000 epsilon: 0.000010 act: relu is_train: False
# [TL] Conv2d SRGAN_g/n64s1/c2/11: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b2/11: decay: 0.900000 epsilon: 0.000010 act: No Activation is_train: False
# [TL] ElementwiseLayer SRGAN_g/b_residual_add/11: size: (25, 56, 56, 64) fn: add
# [TL] Conv2d SRGAN_g/n64s1/c1/12: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b1/12: decay: 0.900000 epsilon: 0.000010 act: relu is_train: False
# [TL] Conv2d SRGAN_g/n64s1/c2/12: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b2/12: decay: 0.900000 epsilon: 0.000010 act: No Activation is_train: False
# [TL] ElementwiseLayer SRGAN_g/b_residual_add/12: size: (25, 56, 56, 64) fn: add
# [TL] Conv2d SRGAN_g/n64s1/c1/13: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b1/13: decay: 0.900000 epsilon: 0.000010 act: relu is_train: False
# [TL] Conv2d SRGAN_g/n64s1/c2/13: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b2/13: decay: 0.900000 epsilon: 0.000010 act: No Activation is_train: False
# [TL] ElementwiseLayer SRGAN_g/b_residual_add/13: size: (25, 56, 56, 64) fn: add
# [TL] Conv2d SRGAN_g/n64s1/c1/14: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b1/14: decay: 0.900000 epsilon: 0.000010 act: relu is_train: False
# [TL] Conv2d SRGAN_g/n64s1/c2/14: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b2/14: decay: 0.900000 epsilon: 0.000010 act: No Activation is_train: False
# [TL] ElementwiseLayer SRGAN_g/b_residual_add/14: size: (25, 56, 56, 64) fn: add
# [TL] Conv2d SRGAN_g/n64s1/c1/15: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b1/15: decay: 0.900000 epsilon: 0.000010 act: relu is_train: False
# [TL] Conv2d SRGAN_g/n64s1/c2/15: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b2/15: decay: 0.900000 epsilon: 0.000010 act: No Activation is_train: False
# [TL] ElementwiseLayer SRGAN_g/b_residual_add/15: size: (25, 56, 56, 64) fn: add
# [TL] Conv2d SRGAN_g/n64s1/c/m: n_filter: 64 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] BatchNormLayer SRGAN_g/n64s1/b/m: decay: 0.900000 epsilon: 0.000010 act: No Activation is_train: False
# [TL] ElementwiseLayer SRGAN_g/add3: size: (25, 56, 56, 64) fn: add
# [TL] Conv2d SRGAN_g/n256s1/1: n_filter: 256 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] SubpixelConv2d  SRGAN_g/pixelshufflerx2/1: scale: 2 n_out_channel: 64 act: relu
# [TL] Conv2d SRGAN_g/n256s1/2: n_filter: 256 filter_size: (3, 3) strides: (1, 1) pad: SAME act: No Activation
# [TL] SubpixelConv2d  SRGAN_g/pixelshufflerx2/2: scale: 2 n_out_channel: 64 act: relu
# [TL] Conv2d SRGAN_g/out: n_filter: 3 filter_size: (1, 1) strides: (1, 1) pad: SAME act: tanh

# %%
# ###========================== DEFINE TRAIN OPS ==========================###
d_loss1 = tl.cost.sigmoid_cross_entropy(logits_real, tf.ones_like(logits_real), name='d1')
d_loss2 = tl.cost.sigmoid_cross_entropy(logits_fake, tf.zeros_like(logits_fake), name='d2')
d_loss = d_loss1 + d_loss2

g_gan_loss = 1e-3 * tl.cost.sigmoid_cross_entropy(logits_fake, tf.ones_like(logits_fake), name='g')
mse_loss = tl.cost.mean_squared_error(net_g.outputs, t_target_image, is_mean=True)
vgg_loss = 2e-6 * tl.cost.mean_squared_error(vgg_predict_emb.outputs, vgg_target_emb.outputs, is_mean=True)

g_loss = mse_loss + vgg_loss + g_gan_loss

g_vars = tl.layers.get_variables_with_name('SRGAN_g', True, True)
d_vars = tl.layers.get_variables_with_name('SRGAN_d', True, True)

with tf.variable_scope('learning_rate'):
    lr_v = tf.Variable(lr_init, trainable=False)
# Out:
# [TL]   [*] geting variables with SRGAN_g
# [TL]   got   0: SRGAN_g/n64s1/c/kernel:0   (3, 3, 3, 64)
# [TL]   got   1: SRGAN_g/n64s1/c/bias:0   (64,)
# [TL]   got   2: SRGAN_g/n64s1/c1/0/kernel:0   (3, 3, 64, 64)
# [TL]   got   3: SRGAN_g/n64s1/b1/0/beta:0   (64,)
# [TL]   got   4: SRGAN_g/n64s1/b1/0/gamma:0   (64,)
# [TL]   got   5: SRGAN_g/n64s1/c2/0/kernel:0   (3, 3, 64, 64)
# [TL]   got   6: SRGAN_g/n64s1/b2/0/beta:0   (64,)
# [TL]   got   7: SRGAN_g/n64s1/b2/0/gamma:0   (64,)
# [TL]   got   8: SRGAN_g/n64s1/c1/1/kernel:0   (3, 3, 64, 64)
# [TL]   got   9: SRGAN_g/n64s1/b1/1/beta:0   (64,)
# [TL]   got  10: SRGAN_g/n64s1/b1/1/gamma:0   (64,)
# [TL]   got  11: SRGAN_g/n64s1/c2/1/kernel:0   (3, 3, 64, 64)
# [TL]   got  12: SRGAN_g/n64s1/b2/1/beta:0   (64,)
# [TL]   got  13: SRGAN_g/n64s1/b2/1/gamma:0   (64,)
# [TL]   got  14: SRGAN_g/n64s1/c1/2/kernel:0   (3, 3, 64, 64)
# [TL]   got  15: SRGAN_g/n64s1/b1/2/beta:0   (64,)
# [TL]   got  16: SRGAN_g/n64s1/b1/2/gamma:0   (64,)
# [TL]   got  17: SRGAN_g/n64s1/c2/2/kernel:0   (3, 3, 64, 64)
# [TL]   got  18: SRGAN_g/n64s1/b2/2/beta:0   (64,)
# [TL]   got  19: SRGAN_g/n64s1/b2/2/gamma:0   (64,)
# [TL]   got  20: SRGAN_g/n64s1/c1/3/kernel:0   (3, 3, 64, 64)
# [TL]   got  21: SRGAN_g/n64s1/b1/3/beta:0   (64,)
# [TL]   got  22: SRGAN_g/n64s1/b1/3/gamma:0   (64,)
# [TL]   got  23: SRGAN_g/n64s1/c2/3/kernel:0   (3, 3, 64, 64)
# [TL]   got  24: SRGAN_g/n64s1/b2/3/beta:0   (64,)
# [TL]   got  25: SRGAN_g/n64s1/b2/3/gamma:0   (64,)
# [TL]   got  26: SRGAN_g/n64s1/c1/4/kernel:0   (3, 3, 64, 64)
# [TL]   got  27: SRGAN_g/n64s1/b1/4/beta:0   (64,)
# [TL]   got  28: SRGAN_g/n64s1/b1/4/gamma:0   (64,)
# [TL]   got  29: SRGAN_g/n64s1/c2/4/kernel:0   (3, 3, 64, 64)
# [TL]   got  30: SRGAN_g/n64s1/b2/4/beta:0   (64,)
# [TL]   got  31: SRGAN_g/n64s1/b2/4/gamma:0   (64,)
# [TL]   got  32: SRGAN_g/n64s1/c1/5/kernel:0   (3, 3, 64, 64)
# [TL]   got  33: SRGAN_g/n64s1/b1/5/beta:0   (64,)
# [TL]   got  34: SRGAN_g/n64s1/b1/5/gamma:0   (64,)
# [TL]   got  35: SRGAN_g/n64s1/c2/5/kernel:0   (3, 3, 64, 64)
# [TL]   got  36: SRGAN_g/n64s1/b2/5/beta:0   (64,)
# [TL]   got  37: SRGAN_g/n64s1/b2/5/gamma:0   (64,)
# [TL]   got  38: SRGAN_g/n64s1/c1/6/kernel:0   (3, 3, 64, 64)
# [TL]   got  39: SRGAN_g/n64s1/b1/6/beta:0   (64,)
# [TL]   got  40: SRGAN_g/n64s1/b1/6/gamma:0   (64,)
# [TL]   got  41: SRGAN_g/n64s1/c2/6/kernel:0   (3, 3, 64, 64)
# [TL]   got  42: SRGAN_g/n64s1/b2/6/beta:0   (64,)
# [TL]   got  43: SRGAN_g/n64s1/b2/6/gamma:0   (64,)
# [TL]   got  44: SRGAN_g/n64s1/c1/7/kernel:0   (3, 3, 64, 64)
# [TL]   got  45: SRGAN_g/n64s1/b1/7/beta:0   (64,)
# [TL]   got  46: SRGAN_g/n64s1/b1/7/gamma:0   (64,)
# [TL]   got  47: SRGAN_g/n64s1/c2/7/kernel:0   (3, 3, 64, 64)
# [TL]   got  48: SRGAN_g/n64s1/b2/7/beta:0   (64,)
# [TL]   got  49: SRGAN_g/n64s1/b2/7/gamma:0   (64,)
# [TL]   got  50: SRGAN_g/n64s1/c1/8/kernel:0   (3, 3, 64, 64)
# [TL]   got  51: SRGAN_g/n64s1/b1/8/beta:0   (64,)
# [TL]   got  52: SRGAN_g/n64s1/b1/8/gamma:0   (64,)
# [TL]   got  53: SRGAN_g/n64s1/c2/8/kernel:0   (3, 3, 64, 64)
# [TL]   got  54: SRGAN_g/n64s1/b2/8/beta:0   (64,)
# [TL]   got  55: SRGAN_g/n64s1/b2/8/gamma:0   (64,)
# [TL]   got  56: SRGAN_g/n64s1/c1/9/kernel:0   (3, 3, 64, 64)
# [TL]   got  57: SRGAN_g/n64s1/b1/9/beta:0   (64,)
# [TL]   got  58: SRGAN_g/n64s1/b1/9/gamma:0   (64,)
# [TL]   got  59: SRGAN_g/n64s1/c2/9/kernel:0   (3, 3, 64, 64)
# [TL]   got  60: SRGAN_g/n64s1/b2/9/beta:0   (64,)
# [TL]   got  61: SRGAN_g/n64s1/b2/9/gamma:0   (64,)
# [TL]   got  62: SRGAN_g/n64s1/c1/10/kernel:0   (3, 3, 64, 64)
# [TL]   got  63: SRGAN_g/n64s1/b1/10/beta:0   (64,)
# [TL]   got  64: SRGAN_g/n64s1/b1/10/gamma:0   (64,)
# [TL]   got  65: SRGAN_g/n64s1/c2/10/kernel:0   (3, 3, 64, 64)
# [TL]   got  66: SRGAN_g/n64s1/b2/10/beta:0   (64,)
# [TL]   got  67: SRGAN_g/n64s1/b2/10/gamma:0   (64,)
# [TL]   got  68: SRGAN_g/n64s1/c1/11/kernel:0   (3, 3, 64, 64)
# [TL]   got  69: SRGAN_g/n64s1/b1/11/beta:0   (64,)
# [TL]   got  70: SRGAN_g/n64s1/b1/11/gamma:0   (64,)
# [TL]   got  71: SRGAN_g/n64s1/c2/11/kernel:0   (3, 3, 64, 64)
# [TL]   got  72: SRGAN_g/n64s1/b2/11/beta:0   (64,)
# [TL]   got  73: SRGAN_g/n64s1/b2/11/gamma:0   (64,)
# [TL]   got  74: SRGAN_g/n64s1/c1/12/kernel:0   (3, 3, 64, 64)
# [TL]   got  75: SRGAN_g/n64s1/b1/12/beta:0   (64,)
# [TL]   got  76: SRGAN_g/n64s1/b1/12/gamma:0   (64,)
# [TL]   got  77: SRGAN_g/n64s1/c2/12/kernel:0   (3, 3, 64, 64)
# [TL]   got  78: SRGAN_g/n64s1/b2/12/beta:0   (64,)
# [TL]   got  79: SRGAN_g/n64s1/b2/12/gamma:0   (64,)
# [TL]   got  80: SRGAN_g/n64s1/c1/13/kernel:0   (3, 3, 64, 64)
# [TL]   got  81: SRGAN_g/n64s1/b1/13/beta:0   (64,)
# [TL]   got  82: SRGAN_g/n64s1/b1/13/gamma:0   (64,)
# [TL]   got  83: SRGAN_g/n64s1/c2/13/kernel:0   (3, 3, 64, 64)
# [TL]   got  84: SRGAN_g/n64s1/b2/13/beta:0   (64,)
# [TL]   got  85: SRGAN_g/n64s1/b2/13/gamma:0   (64,)
# [TL]   got  86: SRGAN_g/n64s1/c1/14/kernel:0   (3, 3, 64, 64)
# [TL]   got  87: SRGAN_g/n64s1/b1/14/beta:0   (64,)
# [TL]   got  88: SRGAN_g/n64s1/b1/14/gamma:0   (64,)
# [TL]   got  89: SRGAN_g/n64s1/c2/14/kernel:0   (3, 3, 64, 64)
# [TL]   got  90: SRGAN_g/n64s1/b2/14/beta:0   (64,)
# [TL]   got  91: SRGAN_g/n64s1/b2/14/gamma:0   (64,)
# [TL]   got  92: SRGAN_g/n64s1/c1/15/kernel:0   (3, 3, 64, 64)
# [TL]   got  93: SRGAN_g/n64s1/b1/15/beta:0   (64,)
# [TL]   got  94: SRGAN_g/n64s1/b1/15/gamma:0   (64,)
# [TL]   got  95: SRGAN_g/n64s1/c2/15/kernel:0   (3, 3, 64, 64)
# [TL]   got  96: SRGAN_g/n64s1/b2/15/beta:0   (64,)
# [TL]   got  97: SRGAN_g/n64s1/b2/15/gamma:0   (64,)
# [TL]   got  98: SRGAN_g/n64s1/c/m/kernel:0   (3, 3, 64, 64)
# [TL]   got  99: SRGAN_g/n64s1/b/m/beta:0   (64,)
# [TL]   got 100: SRGAN_g/n64s1/b/m/gamma:0   (64,)
# [TL]   got 101: SRGAN_g/n256s1/1/kernel:0   (3, 3, 64, 256)
# [TL]   got 102: SRGAN_g/n256s1/1/bias:0   (256,)
# [TL]   got 103: SRGAN_g/n256s1/2/kernel:0   (3, 3, 64, 256)
# [TL]   got 104: SRGAN_g/n256s1/2/bias:0   (256,)
# [TL]   got 105: SRGAN_g/out/kernel:0   (1, 1, 64, 3)
# [TL]   got 106: SRGAN_g/out/bias:0   (3,)
# [TL]   [*] geting variables with SRGAN_d
# [TL]   got   0: SRGAN_d/h0/c/kernel:0   (4, 4, 3, 64)
# [TL]   got   1: SRGAN_d/h0/c/bias:0   (64,)
# [TL]   got   2: SRGAN_d/h1/c/kernel:0   (4, 4, 64, 128)
# [TL]   got   3: SRGAN_d/h1/bn/beta:0   (128,)
# [TL]   got   4: SRGAN_d/h1/bn/gamma:0   (128,)
# [TL]   got   5: SRGAN_d/h2/c/kernel:0   (4, 4, 128, 256)
# [TL]   got   6: SRGAN_d/h2/bn/beta:0   (256,)
# [TL]   got   7: SRGAN_d/h2/bn/gamma:0   (256,)
# [TL]   got   8: SRGAN_d/h3/c/kernel:0   (4, 4, 256, 512)
# [TL]   got   9: SRGAN_d/h3/bn/beta:0   (512,)
# [TL]   got  10: SRGAN_d/h3/bn/gamma:0   (512,)
# [TL]   got  11: SRGAN_d/h4/c/kernel:0   (4, 4, 512, 1024)
# [TL]   got  12: SRGAN_d/h4/bn/beta:0   (1024,)
# [TL]   got  13: SRGAN_d/h4/bn/gamma:0   (1024,)
# [TL]   got  14: SRGAN_d/h5/c/kernel:0   (4, 4, 1024, 2048)
# [TL]   got  15: SRGAN_d/h5/bn/beta:0   (2048,)
# [TL]   got  16: SRGAN_d/h5/bn/gamma:0   (2048,)
# [TL]   got  17: SRGAN_d/h6/c/kernel:0   (1, 1, 2048, 1024)
# [TL]   got  18: SRGAN_d/h6/bn/beta:0   (1024,)
# [TL]   got  19: SRGAN_d/h6/bn/gamma:0   (1024,)
# [TL]   got  20: SRGAN_d/h7/c/kernel:0   (1, 1, 1024, 512)
# [TL]   got  21: SRGAN_d/h7/bn/beta:0   (512,)
# [TL]   got  22: SRGAN_d/h7/bn/gamma:0   (512,)
# [TL]   got  23: SRGAN_d/res/c/kernel:0   (1, 1, 512, 128)
# [TL]   got  24: SRGAN_d/res/bn/beta:0   (128,)
# [TL]   got  25: SRGAN_d/res/bn/gamma:0   (128,)
# [TL]   got  26: SRGAN_d/res/c2/kernel:0   (3, 3, 128, 128)
# [TL]   got  27: SRGAN_d/res/bn2/beta:0   (128,)
# [TL]   got  28: SRGAN_d/res/bn2/gamma:0   (128,)
# [TL]   got  29: SRGAN_d/res/c3/kernel:0   (3, 3, 128, 512)
# [TL]   got  30: SRGAN_d/res/bn3/beta:0   (512,)
# [TL]   got  31: SRGAN_d/res/bn3/gamma:0   (512,)
# [TL]   got  32: SRGAN_d/ho/dense/W:0   (8192, 1)
# [TL]   got  33: SRGAN_d/ho/dense/b:0   (1,)

# %%
g_optim_init = tf.train.AdamOptimizer(lr_v, beta1=beta1).minimize(mse_loss, var_list=g_vars)
## SRGAN
g_optim = tf.train.AdamOptimizer(lr_v, beta1=beta1).minimize(g_loss, var_list=g_vars)
d_optim = tf.train.AdamOptimizer(lr_v, beta1=beta1).minimize(d_loss, var_list=d_vars)
# Out:
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/srgan/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
###========================== RESTORE MODEL =============================###
sess = tf.Session(config=tf.ConfigProto(allow_soft_placement=True, log_device_placement=False))
tl.layers.initialize_global_variables(sess)
'''if tl.files.load_and_assign_npz(sess=sess, name=checkpoint_dir + '/g_{}.npz'.format("srgan"), network=net_g) is False:
    tl.files.load_and_assign_npz(sess=sess, name=checkpoint_dir + '/g_{}_init.npz'.format("srgan"), network=net_g)'''
tl.files.load_and_assign_npz(sess=sess, name='savedModels' + '/g_{}.npz'.format("srgan"), network=net_g)
tl.files.load_and_assign_npz(sess=sess, name='savedModels' + '/d_{}.npz'.format("srgan"), network=net_d)
# Out:
# [TL] WARNING: Function: `tensorlayer.layers.utils.initialize_global_variables` (in file: /home/ubuntu/anaconda3/envs/srgan/lib/python3.7/site-packages/tensorlayer/layers/utils.py) is deprecated and will be removed after 2018-09-30.
# Instructions for updating: This API is deprecated in favor of `tf.global_variables_initializer`
#
# [TL] [*] Load savedModels/g_srgan.npz SUCCESS!
# [TL] ERROR: file savedModels/d_srgan.npz doesn't exist.

# %%
###============================= LOAD VGG ===============================###
vgg19_npy_path = "../vgg19.npy"
if not os.path.isfile(vgg19_npy_path):
    print("Please download vgg19.npz from : https://github.com/machrisaa/tensorflow-vgg")
    exit()
npz = np.load(vgg19_npy_path, encoding='latin1').item()

params = []
for val in sorted(npz.items()):
    W = np.asarray(val[1][0])
    b = np.asarray(val[1][1])
    print("  Loading %s: %s, %s" % (val[0], W.shape, b.shape))
    params.extend([W, b])
tl.files.assign_params(sess, params, net_vgg)
# net_vgg.print_params(False)
# net_vgg.print_layers()
# Out:
#   Loading conv1_1: (3, 3, 3, 64), (64,)
#   Loading conv1_2: (3, 3, 64, 64), (64,)
#   Loading conv2_1: (3, 3, 64, 128), (128,)
#   Loading conv2_2: (3, 3, 128, 128), (128,)
#   Loading conv3_1: (3, 3, 128, 256), (256,)
#   Loading conv3_2: (3, 3, 256, 256), (256,)
#   Loading conv3_3: (3, 3, 256, 256), (256,)
#   Loading conv3_4: (3, 3, 256, 256), (256,)
#   Loading conv4_1: (3, 3, 256, 512), (512,)
#   Loading conv4_2: (3, 3, 512, 512), (512,)
#   Loading conv4_3: (3, 3, 512, 512), (512,)
#   Loading conv4_4: (3, 3, 512, 512), (512,)
#   Loading conv5_1: (3, 3, 512, 512), (512,)
#   Loading conv5_2: (3, 3, 512, 512), (512,)
#   Loading conv5_3: (3, 3, 512, 512), (512,)
#   Loading conv5_4: (3, 3, 512, 512), (512,)
#   Loading fc6: (25088, 4096), (4096,)
#   Loading fc7: (4096, 4096), (4096,)
#   Loading fc8: (4096, 1000), (1000,)
# [<tf.Tensor 'Assign_173:0' shape=(3, 3, 3, 64) dtype=float32_ref>,
#  <tf.Tensor 'Assign_174:0' shape=(64,) dtype=float32_ref>,
#  <tf.Tensor 'Assign_175:0' shape=(3, 3, 64, 64) dtype=float32_ref>,
#  <tf.Tensor 'Assign_176:0' shape=(64,) dtype=float32_ref>,
#  <tf.Tensor 'Assign_177:0' shape=(3, 3, 64, 128) dtype=float32_ref>,
#  <tf.Tensor 'Assign_178:0' shape=(128,) dtype=float32_ref>,
#  <tf.Tensor 'Assign_179:0' shape=(3, 3, 128, 128) dtype=float32_ref>,
#  <tf.Tensor 'Assign_180:0' shape=(128,) dtype=float32_ref>,
#  <tf.Tensor 'Assign_181:0' shape=(3, 3, 128, 256) dtype=float32_ref>,
#  <tf.Tensor 'Assign_182:0' shape=(256,) dtype=float32_ref>,
#  <tf.Tensor 'Assign_183:0' shape=(3, 3, 256, 256) dtype=float32_ref>,
#  <tf.Tensor 'Assign_184:0' shape=(256,) dtype=float32_ref>,
#  <tf.Tensor 'Assign_185:0' shape=(3, 3, 256, 256) dtype=float32_ref>,
#  <tf.Tensor 'Assign_186:0' shape=(256,) dtype=float32_ref>,
#  <tf.Tensor 'Assign_187:0' shape=(3, 3, 256, 256) dtype=float32_ref>,
#  <tf.Tensor 'Assign_188:0' shape=(256,) dtype=float32_ref>,
#  <tf.Tensor 'Assign_189:0' shape=(3, 3, 256, 512) dtype=float32_ref>,
#  <tf.Tensor 'Assign_190:0' shape=(512,) dtype=float32_ref>,
#  <tf.Tensor 'Assign_191:0' shape=(3, 3, 512, 512) dtype=float32_ref>,
#  <tf.Tensor 'Assign_192:0' shape=(512,) dtype=float32_ref>,
#  <tf.Tensor 'Assign_193:0' shape=(3, 3, 512, 512) dtype=float32_ref>,
#  <tf.Tensor 'Assign_194:0' shape=(512,) dtype=float32_ref>,
#  <tf.Tensor 'Assign_195:0' shape=(3, 3, 512, 512) dtype=float32_ref>,
#  <tf.Tensor 'Assign_196:0' shape=(512,) dtype=float32_ref>,
#  <tf.Tensor 'Assign_197:0' shape=(3, 3, 512, 512) dtype=float32_ref>,
#  <tf.Tensor 'Assign_198:0' shape=(512,) dtype=float32_ref>,
#  <tf.Tensor 'Assign_199:0' shape=(3, 3, 512, 512) dtype=float32_ref>,
#  <tf.Tensor 'Assign_200:0' shape=(512,) dtype=float32_ref>,
#  <tf.Tensor 'Assign_201:0' shape=(3, 3, 512, 512) dtype=float32_ref>,
#  <tf.Tensor 'Assign_202:0' shape=(512,) dtype=float32_ref>,
#  <tf.Tensor 'Assign_203:0' shape=(3, 3, 512, 512) dtype=float32_ref>,
#  <tf.Tensor 'Assign_204:0' shape=(512,) dtype=float32_ref>,
#  <tf.Tensor 'Assign_205:0' shape=(25088, 4096) dtype=float32_ref>,
#  <tf.Tensor 'Assign_206:0' shape=(4096,) dtype=float32_ref>,
#  <tf.Tensor 'Assign_207:0' shape=(4096, 4096) dtype=float32_ref>,
#  <tf.Tensor 'Assign_208:0' shape=(4096,) dtype=float32_ref>,
#  <tf.Tensor 'Assign_209:0' shape=(4096, 1000) dtype=float32_ref>,
#  <tf.Tensor 'Assign_210:0' shape=(1000,) dtype=float32_ref>]

# %%
def train_hr_imgs_datagen(train_hr_imgs,batch_size):
    while True:
        idx = np.random.randint(0,len(train_hr_imgs),batch_size)
        yield [train_hr_imgs[x] for x in idx]

# %%
# Create the TensorBoard callback,
# which we will drive manually
tensorboard = TensorBoard(
  log_dir='log/run9',
  histogram_freq=0,
  batch_size=batchSize,
  write_graph=True,
  write_grads=True
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-36efe057e90a> in <module>
#       1 # Create the TensorBoard callback,
#       2 # which we will drive manually
# ----> 3 tensorboard = TensorBoard(
#       4   log_dir='log/run9',
#       5   histogram_freq=0,
#
# NameError: name 'TensorBoard' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-30-9977f288f8e4> in <module>
# ----> 1 from tensorflow import tensorboard
#
# ImportError: cannot import name 'tensorboard' from 'tensorflow' (/home/ubuntu/anaconda3/envs/srgan/lib/python3.7/site-packages/tensorflow/__init__.py)

# %%
sess.run(tf.assign(lr_v, lr_init))
print(" ** fixed learning rate: %f (for init G)" % lr_init)
datagen = train_hr_imgs_datagen(train_hr_imgs,batch_size)
train_writer = tf.summary.FileWriter( './logs/1/train ', sess.graph)
for epoch in range(0, n_epoch_init + 1):
    epoch_time = time.time()
    total_mse_loss, n_iter = 0, 0

    ## If your machine cannot load all images into memory, you should use
    ## this one to load batch of images while training.
    # random.shuffle(train_hr_img_list)
    # for idx in range(0, len(train_hr_img_list), batch_size):
    #     step_time = time.time()
    #     b_imgs_list = train_hr_img_list[idx : idx + batch_size]
    #     b_imgs = tl.prepro.threading_data(b_imgs_list, fn=get_imgs_fn, path=config.TRAIN.hr_img_path)
    #     b_imgs_384 = tl.prepro.threading_data(b_imgs, fn=crop_sub_imgs_fn, is_random=True)
    #     b_imgs_96 = tl.prepro.threading_data(b_imgs_384, fn=downsample_fn)

    ## If your machine have enough memory, please pre-load the whole train set.
    random.shuffle(train_hr_img_list)
    for idx in range(0, len(train_hr_imgs), batch_size):
        step_time = time.time()        
        b_imgs_384 = tl.prepro.threading_data(train_hr_imgs, fn=crop_sub_imgs_fn, dim=cropDim, is_random=True)
        b_imgs_96 = tl.prepro.threading_data(train_hr_imgs, fn=downsample_fn,dim=int(cropDim/4))
        #b_imgs_384 = tl.prepro.threading_data(next(datagen), fn=crop_sub_imgs_fn,dim=cropDim, is_random=True)
        #b_imgs_96 = tl.prepro.threading_data(b_imgs_384, fn=downsample_fn,dim=int(cropDim/4))
        ## update G
        errM, _ = sess.run([mse_loss, g_optim_init], {t_image: b_imgs_96, t_target_image: b_imgs_384})
        
        print("Epoch [%2d/%2d] %4d time: %4.4fs, mse: %.8f " % (epoch, n_epoch_init, n_iter, time.time() - step_time, errM))
        total_mse_loss += errM
        n_iter += 1
    log = "[*] Epoch: [%2d/%2d] time: %4.4fs, mse: %.8f" % (epoch, n_epoch_init, time.time() - epoch_time, total_mse_loss / n_iter)
    print(log)

    ## quick evaluation on train set
    if (epoch != 0) and (epoch % 1 == 0):
        out = sess.run(net_g_test.outputs, {t_image: sample_imgs_56})  #; print('gen sub-image:', out.shape, out.min(), out.max())
        print("[*] save images")
        tl.vis.save_images(out, [ni, ni], save_dir_ginit + '/train_%d.png' % epoch)

    ## save model
    if (epoch != 0) and (epoch % 10 == 0):
        tl.files.save_npz(net_g.all_params, name=checkpoint_dir + '/g_{}_init.npz'.format("train"), sess=sess)
# Out:
#  ** fixed learning rate: 0.000100 (for init G)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-3f22f2ecf83d> in <module>
#      25         #b_imgs_96 = tl.prepro.threading_data(b_imgs_384, fn=downsample_fn,dim=int(cropDim/4))
#      26         ## update G
# ---> 27         errM, _ = sess.run([mse_loss, g_optim_init], {t_image: b_imgs_96, t_target_image: b_imgs_384})
#      28         print("Epoch [%2d/%2d] %4d time: %4.4fs, mse: %.8f " % (epoch, n_epoch_init, n_iter, time.time() - step_time, errM))
#      29         total_mse_loss += errM
#
# ~/anaconda3/envs/srgan/lib/python3.7/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/envs/srgan/lib/python3.7/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1126                              'which has shape %r' %
#    1127                              (np_val.shape, subfeed_t.name,
# -> 1128                               str(subfeed_t.get_shape())))
#    1129           if not self.graph.is_feedable(subfeed_t):
#    1130             raise ValueError('Tensor %s may not be fed.' % subfeed_t)
#
# ValueError: Cannot feed value of shape (2920, 56, 56, 3) for Tensor 't_image_input_to_SRGAN_generator:0', which has shape '(25, 56, 56, 3)'

# %%
###========================= train GAN (SRGAN) =========================###
for epoch in range(0, n_epoch + 1):
    ## update learning rate
    if epoch != 0 and (epoch % decay_every == 0):
        new_lr_decay = lr_decay**(epoch // decay_every)
        sess.run(tf.assign(lr_v, lr_init * new_lr_decay))
        log = " ** new learning rate: %f (for GAN)" % (lr_init * new_lr_decay)
        print(log)
    elif epoch == 0:
        sess.run(tf.assign(lr_v, lr_init))
        log = " ** init lr: %f  decay_every_init: %d, lr_decay: %f (for GAN)" % (lr_init, decay_every, lr_decay)
        print(log)

    epoch_time = time.time()
    total_d_loss, total_g_loss, n_iter = 0, 0, 0

    ## If your machine cannot load all images into memory, you should use
    ## this one to load batch of images while training.
    # random.shuffle(train_hr_img_list)
    # for idx in range(0, len(train_hr_img_list), batch_size):
    #     step_time = time.time()
    #     b_imgs_list = train_hr_img_list[idx : idx + batch_size]
    #     b_imgs = tl.prepro.threading_data(b_imgs_list, fn=get_imgs_fn, path=config.TRAIN.hr_img_path)
    #     b_imgs_384 = tl.prepro.threading_data(b_imgs, fn=crop_sub_imgs_fn, is_random=True)
    #     b_imgs_96 = tl.prepro.threading_data(b_imgs_384, fn=downsample_fn)

    ## If your machine have enough memory, please pre-load the whole train set.
    for idx in range(0, len(train_hr_imgs), batch_size):
        step_time = time.time()
        b_imgs_384 = tl.prepro.threading_data(next(datagen), fn=crop_sub_imgs_fn,dim = cropDim, is_random=True)
        b_imgs_96 = tl.prepro.threading_data(b_imgs_384, fn=downsample_fn,dim=int(cropDim/4))
        ## update D
        errD, _ = sess.run([d_loss, d_optim], {t_image: b_imgs_96, t_target_image: b_imgs_384})
        ## update G
        errG, errM, errV, errA, _ = sess.run([g_loss, mse_loss, vgg_loss, g_gan_loss, g_optim], {t_image: b_imgs_96, t_target_image: b_imgs_384})
        print("Epoch [%2d/%2d] %4d time: %4.4fs, d_loss: %.8f g_loss: %.8f (mse: %.6f vgg: %.6f adv: %.6f)" %
              (epoch, n_epoch, n_iter, time.time() - step_time, errD, errG, errM, errV, errA))
        total_d_loss += errD
        total_g_loss += errG
        n_iter += 1

    log = "[*] Epoch: [%2d/%2d] time: %4.4fs, d_loss: %.8f g_loss: %.8f" % (epoch, n_epoch, time.time() - epoch_time, total_d_loss / n_iter,
                                                                            total_g_loss / n_iter)
    print(log)

    ## quick evaluation on train set
    if (epoch != 0) and (epoch % 10 == 0):
        out = sess.run(net_g_test.outputs, {t_image: sample_imgs_56})  #; print('gen sub-image:', out.shape, out.min(), out.max())
        print("[*] save images")
        tl.vis.save_images(out, [ni, ni], save_dir_gan + '/train_%d.png' % epoch)

    ## save model
    if (epoch != 0) and (epoch % 10 == 0):
        tl.files.save_npz(net_g.all_params, name=checkpoint_dir + '/g_{}.npz'.format("train"), sess=sess)
        tl.files.save_npz(net_d.all_params, name=checkpoint_dir + '/d_{}.npz'.format("train"), sess=sess)
# Out:
#  ** init lr: 0.000100  decay_every_init: 25, lr_decay: 0.000000 (for GAN)
# Epoch [ 0/1000]    0 time: 23.2213s, d_loss: 2.02643013 g_loss: 0.07027414 (mse: 0.030769 vgg: 0.033019 adv: 0.006485)
# Epoch [ 0/1000]    1 time: 2.8893s, d_loss: 3.20976257 g_loss: 0.07373558 (mse: 0.038615 vgg: 0.030571 adv: 0.004550)
# Epoch [ 0/1000]    2 time: 2.8836s, d_loss: 3.14896226 g_loss: 0.06294714 (mse: 0.029146 vgg: 0.031610 adv: 0.002190)
# Epoch [ 0/1000]    3 time: 2.8783s, d_loss: 2.46014833 g_loss: 0.07489321 (mse: 0.032075 vgg: 0.039581 adv: 0.003237)
# Epoch [ 0/1000]    4 time: 2.8953s, d_loss: 1.87300801 g_loss: 0.05651864 (mse: 0.024050 vgg: 0.029824 adv: 0.002645)
# Epoch [ 0/1000]    5 time: 2.9004s, d_loss: 2.49380851 g_loss: 0.05762159 (mse: 0.019912 vgg: 0.036958 adv: 0.000752)
# Epoch [ 0/1000]    6 time: 2.8897s, d_loss: 2.06549168 g_loss: 0.13754508 (mse: 0.098246 vgg: 0.038471 adv: 0.000829)
# Epoch [ 0/1000]    7 time: 2.9063s, d_loss: 2.26766849 g_loss: 0.06764884 (mse: 0.030535 vgg: 0.035699 adv: 0.001415)
# Epoch [ 0/1000]    8 time: 2.9011s, d_loss: 2.41171360 g_loss: 0.05427468 (mse: 0.019902 vgg: 0.032642 adv: 0.001730)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-45-fd26c2741fa1> in <module>
#      33         errD, _ = sess.run([d_loss, d_optim], {t_image: b_imgs_96, t_target_image: b_imgs_384})
#      34         ## update G
# ---> 35         errG, errM, errV, errA, _ = sess.run([g_loss, mse_loss, vgg_loss, g_gan_loss, g_optim], {t_image: b_imgs_96, t_target_image: b_imgs_384})
#      36         print("Epoch [%2d/%2d] %4d time: %4.4fs, d_loss: %.8f g_loss: %.8f (mse: %.6f vgg: %.6f adv: %.6f)" %
#      37               (epoch, n_epoch, n_iter, time.time() - step_time, errD, errG, errM, errV, errA))
#
# ~/anaconda3/envs/srgan/lib/python3.7/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/envs/srgan/lib/python3.7/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# ~/anaconda3/envs/srgan/lib/python3.7/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/anaconda3/envs/srgan/lib/python3.7/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1332   def _do_call(self, fn, *args):
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#    1336       message = compat.as_text(e.message)
#
# ~/anaconda3/envs/srgan/lib/python3.7/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1317       self._extend_graph()
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#    1321     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~/anaconda3/envs/srgan/lib/python3.7/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1405     return tf_session.TF_SessionRun_wrapper(
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#    1409   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
